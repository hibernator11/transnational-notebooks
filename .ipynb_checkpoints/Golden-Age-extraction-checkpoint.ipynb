# %% [markdown]
# # Golden Age: A transnational approach
#
# Influential genres of art and literature from the ancient Greek and the Roman Empire to the Renaissance and the rise of Modernism have made their mark on history. Periods from early 16th century to the late 17th century have been considered the high point in literature and art in several countries.
#
# In this sense, the Dutch Golden Age is a period in the history of Netherlands from 1575 to 1675 in which Dutch science and art were among the most acclaimed in the world. Similarly, the Spanish Golden Age is a period of flourishing in arts and literature in Spain during the 16th and 17th centuries.
#
# GLAM institutions have made a great effort in order to digitise and make openly available in different forms the literature and art produce in this period. In addition, For instance, the Rijksmuseum and the Metropolitan Museum of Art offers different ways of accessing the collection data, such as downloads and APIs. Several corpora have been published including text using standard and interoperable formats. Wikidata have been collaborativelly edited by volunteers and enriched by repositories of all around the world. Other approaches are based on the use of Linked Open Data to track and trace processes of canonization in early modern Dutch literature publishing enriched LOD datasets as a result.
#
# This transnational dataset is based in several repositories that are available in different platforms, using different formats and including different types of materials. Table presents an overview of the sources used including the main features of each of them.
#
#
# |Institution|URL|
# |---|---|
# |Harvard Art Musemums| https://github.com/harvardartmuseums/api-docs |
# |Rijks Museum  | https://www.rijksmuseum.nl/en/data |
# |Wikidata   | https://www.wikidata.org/  |

# %% [markdown]
# ## API requests
# Many GLAM institutions are providing data by means of APIs that require registration. Some examples are the Harvard Art Museums and the Rijksmuseum.
#
# The [Harvard Art Museums API](https://github.com/harvardartmuseums/api-docs) is a REST-style service designed for developers who wish to explore and integrate the museums’ collections in their projects. The API provides direct access to the data that powers the museums' website and many other aspects of the museums. The organization provides a registration form to ask for an API key [Harvard Art Museums API Documentation API key request](https://docs.google.com/forms/d/1Fe1H4nOhFkrLpaeBpLAnSrIMYvcAxnYWm0IU9a6IkFA/viewform).
#
# [Rijksmuseum](https://data.rijksmuseum.nl/) data services provide access to object metadata, bibliographic data, controlled vocabularies and user generated content. To start using the data and images, you first need to obtain an API key by registering for a [Rijksstudio account](https://www.rijksmuseum.nl/en/rijksstudio).

# %% [markdown]
# ## Setting up things
#
# This part is essential to declare all the Python packages that we are going to use through the notebook. Note that packages can be stated in different cells but in order to provide a clean code they should be grouped in one cell.

# %%
import requests as r
import pandas as pd
import json
import matplotlib.pyplot as plt
from pandas.io.json import json_normalize  
from datapackage import Package
from SPARQLWrapper import SPARQLWrapper, JSON
import networkx as nx
from matplotlib.pyplot import figure

rijks_key = 'bfRVDJWA'
ham_key = 'ab62f9f8-395d-4945-b7cf-a854e4557472'

# %% [markdown]
# ## Let's start by querying Wikidata to retrieve a list of authors
#
# We will use the [Wikidata SPARQL endpoint](https://query.wikidata.org/sparql) to create the query and configure the request to retrieve json as a result.
#
# The instruction Bind in SPARQL allows to bind values. In this case we are using [wd:Q2352880](https://www.wikidata.org/wiki/Q2352880) (Spanish Golden Age) and [wd:Q530936](https://www.wikidata.org/wiki/Q530936) (Dutch Golden Age).

# %%
sparql = SPARQLWrapper("https://query.wikidata.org/sparql")

sparql.setQuery("""
SELECT ?item (SAMPLE(?idviaf) as ?viaf) ?itemLabel ?periodLabel
(GROUP_CONCAT(DISTINCT ?educated;separator="|") as ?educatedAt) 
(GROUP_CONCAT(DISTINCT ?influenced;separator="|") as ?influencedBy) 
(GROUP_CONCAT(DISTINCT ?genre;separator="|") as ?genres)
(GROUP_CONCAT(DISTINCT ?languageSpoken;separator="|") as ?languagesSpoken)
WHERE 
{
  {
    VALUES ?period {wd:Q2352880 wd:Q530936} 
    # ?item wdt:P135 ?period.
    # ?item wdt:P31 wd:Q5.
    # ?item wdt:P214 ?idviaf.
    OPTIONAL {?item wdt:P737 ?influenced.}
    OPTIONAL {?item wdt:P136 ?genre.}
    OPTIONAL {?item wdt:P69 ?educated.}
    OPTIONAL {?item wdt:P1412 ?languageSpoken.}
  }
  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en".}
}
GROUP BY ?item ?itemLabel ?viaf ?periodLabel""")
sparql.setReturnFormat(JSON)
results = sparql.query().convert()

# %% [markdown]
# ## Save as a JSON file
#
# The result can be stored as a JSON file.
#
# **Note: the file is already in the Github repository since the query above requires a long time to be executed.**

# %%
with open('golden-age.json', 'w') as json_file:
    json.dump(results, json_file)

# %% [markdown]
# ## Exploring the data
#
# Now we will explore the data. First, we open the JSON file and load the data in a Pandas dataframe. A dataframe in Pandas is a data structure with columns of potentially different types. You can think of it like a spreadsheet or SQL table.

# %%
# Load the JSON file from disk
# This puts the data in a Pandas DataFrame
with open('golden-age.json') as f:
    data = json.load(f)

ga_df = pd.io.json.json_normalize(data['results']['bindings'])    
ga_df.head()
# Out:
# /home/gustavo/.local/lib/python3.6/site-packages/ipykernel_launcher.py:6: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   item.type                                item.value itemLabel.xml:lang  \
# 0       uri  http://www.wikidata.org/entity/Q12023294                 en
# 1       uri  http://www.wikidata.org/entity/Q17343011                 en
# 2       uri   http://www.wikidata.org/entity/Q2359229                 en
# 3       uri   http://www.wikidata.org/entity/Q2486642                 en
# 4       uri   http://www.wikidata.org/entity/Q2576955                 en
#
#   itemLabel.type      itemLabel.value viaf.type viaf.value  \
# 0        literal         Jan van Gool   literal   57416265
# 1        literal   Jacob de Gheyn III   literal   60611905
# 2        literal  Jan Albertsz Rotius   literal   95736294
# 3        literal   David van der Plas   literal   22412408
# 4        literal        Jacob van Loo   literal   95460534
#
#   periodLabel.xml:lang periodLabel.type          periodLabel.value  \
# 0                   en          literal  Dutch Golden Age painting
# 1                   en          literal  Dutch Golden Age painting
# 2                   en          literal  Dutch Golden Age painting
# 3                   en          literal  Dutch Golden Age painting
# 4                   en          literal  Dutch Golden Age painting
#
#   educatedAt.type educatedAt.value influencedBy.type influencedBy.value  \
# 0         literal                            literal
# 1         literal                            literal
# 2         literal                            literal
# 3         literal                            literal
# 4         literal                            literal
#
#   genres.type                                       genres.value  \
# 0     literal
# 1     literal
# 2     literal             http://www.wikidata.org/entity/Q134307
# 3     literal             http://www.wikidata.org/entity/Q134307
# 4     literal  http://www.wikidata.org/entity/Q134307|http://...
#
#   languagesSpoken.type                 languagesSpoken.value
# 0              literal  http://www.wikidata.org/entity/Q7411
# 1              literal
# 2              literal
# 3              literal  http://www.wikidata.org/entity/Q7411
# 4              literal  http://www.wikidata.org/entity/Q7411

# %% [markdown]
# ### Let's see the columns
#
# The Wikidata results are provided in JSON format. Each field are described by means of three columns: datatype, type and value. We are interested in the value column (e.g. birthdate.value).
#
# * item: identifier of the author in Wikidata. Wikidata identifiers starts with a Q.
# * itemLabel: label of the author in Wikidata. For instance, Miguel de Cervantes.
# * id: identifier in the external institution.
# * birthdate
# * deathdate
# * org: this field stores the institution that is linked from Wikidata
# * writtenLanguageLabel
# * deathcauseLabel
# * placeofburial
# * placeofburialLabel
# * geoplaceofburial: coordinates of the place of burial of the author
# * occupationLabel: a list of occupations of the author separated by a '|'

# %%
ga_df.columns
# Out:
# Index(['item.type', 'item.value', 'itemLabel.xml:lang', 'itemLabel.type',
#        'itemLabel.value', 'viaf.type', 'viaf.value', 'periodLabel.xml:lang',
#        'periodLabel.type', 'periodLabel.value', 'educatedAt.type',
#        'educatedAt.value', 'influencedBy.type', 'influencedBy.value',
#        'genres.type', 'genres.value', 'languagesSpoken.type',
#        'languagesSpoken.value'],
#       dtype='object')

# %%
ga_df.loc[ga_df['periodLabel.value'] == 'Dutch Golden Age painting'].head()
# Out:
#   item.type                                item.value itemLabel.xml:lang  \
# 0       uri  http://www.wikidata.org/entity/Q12023294                 en
# 1       uri  http://www.wikidata.org/entity/Q17343011                 en
# 2       uri   http://www.wikidata.org/entity/Q2359229                 en
# 3       uri   http://www.wikidata.org/entity/Q2486642                 en
# 4       uri   http://www.wikidata.org/entity/Q2576955                 en
#
#   itemLabel.type      itemLabel.value viaf.type viaf.value  \
# 0        literal         Jan van Gool   literal   57416265
# 1        literal   Jacob de Gheyn III   literal   60611905
# 2        literal  Jan Albertsz Rotius   literal   95736294
# 3        literal   David van der Plas   literal   22412408
# 4        literal        Jacob van Loo   literal   95460534
#
#   periodLabel.xml:lang periodLabel.type          periodLabel.value  \
# 0                   en          literal  Dutch Golden Age painting
# 1                   en          literal  Dutch Golden Age painting
# 2                   en          literal  Dutch Golden Age painting
# 3                   en          literal  Dutch Golden Age painting
# 4                   en          literal  Dutch Golden Age painting
#
#   educatedAt.type educatedAt.value influencedBy.type influencedBy.value  \
# 0         literal                            literal
# 1         literal                            literal
# 2         literal                            literal
# 3         literal                            literal
# 4         literal                            literal
#
#   genres.type                                       genres.value  \
# 0     literal
# 1     literal
# 2     literal             http://www.wikidata.org/entity/Q134307
# 3     literal             http://www.wikidata.org/entity/Q134307
# 4     literal  http://www.wikidata.org/entity/Q134307|http://...
#
#   languagesSpoken.type                 languagesSpoken.value
# 0              literal  http://www.wikidata.org/entity/Q7411
# 1              literal
# 2              literal
# 3              literal  http://www.wikidata.org/entity/Q7411
# 4              literal  http://www.wikidata.org/entity/Q7411

# %% [markdown]
# ## Creating a RDF graph
#
# Several are the benefits of publishing a dataset using Semantic Web technologies. [RDFLib](https://rdflib.readthedocs.io/en/stable/) is a pure Python package for working with RDF. RDFLib exposes for working with RDF a Graph that is described and enriched by means of triples.
#
# In the following example, we parse the FOAF card of Tim Berners Lee using rdflib.

# %%
import rdflib

# create a Graph
g = rdflib.Graph()

# parse in an RDF file hosted on the Internet
result = g.parse("http://www.w3.org/People/Berners-Lee/card")

# loop through each triple in the graph (subj, pred, obj)
for subj, pred, obj in g:
    # check if there is at least one triple in the Graph
    if (subj, pred, obj) not in g:
       raise Exception("It better be!")

# print the number of "triples" in the Graph
print("graph has {} statements.".format(len(g)))
# prints graph has 86 statements.

# print out the entire Graph in the RDF Turtle format
print(g.serialize(format="turtle").decode("utf-8"))
# Out:
# graph has 86 statements.
# @prefix : <http://xmlns.com/foaf/0.1/> .
# @prefix cc: <http://creativecommons.org/ns#> .
# @prefix cert: <http://www.w3.org/ns/auth/cert#> .
# @prefix con: <http://www.w3.org/2000/10/swap/pim/contact#> .
# @prefix dc: <http://purl.org/dc/elements/1.1/> .
# @prefix dct: <http://purl.org/dc/terms/> .
# @prefix doap: <http://usefulinc.com/ns/doap#> .
# @prefix geo: <http://www.w3.org/2003/01/geo/wgs84_pos#> .
# @prefix ldp: <http://www.w3.org/ns/ldp#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix schema: <http://schema.org/> .
# @prefix sioc: <http://rdfs.org/sioc/ns#> .
# @prefix solid: <http://www.w3.org/ns/solid/terms#> .
# @prefix space: <http://www.w3.org/ns/pim/space#> .
# @prefix vcard: <http://www.w3.org/2006/vcard/ns#> .
# @prefix xml: <http://www.w3.org/XML/1998/namespace> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# <http://dig.csail.mit.edu/2005/ajar/ajaw/data#Tabulator> doap:developer <https://www.w3.org/People/Berners-Lee/card#i> .
#
# <http://dig.csail.mit.edu/2007/01/camp/data#course> :maker <https://www.w3.org/People/Berners-Lee/card#i> .
#
# <http://dig.csail.mit.edu/data#DIG> :member <https://www.w3.org/People/Berners-Lee/card#i> .
#
# <http://wiki.ontoworld.org/index.php/_IRW2006> dc:title "Identity, Reference and the Web workshop 2006" ;
#     con:participant <https://www.w3.org/People/Berners-Lee/card#i> .
#
# <http://www.ecs.soton.ac.uk/~dt2/dlstuff/www2006_data#panel-panelk01> rdfs:label "The Next Wave of the Web (Plenary Panel)" ;
#     con:participant <https://www.w3.org/People/Berners-Lee/card#i> .
#
# <http://www.w3.org/2000/10/swap/data#Cwm> doap:developer <https://www.w3.org/People/Berners-Lee/card#i> .
#
# <http://www.w3.org/2011/Talks/0331-hyderabad-tbl/data#talk> dct:title "Designing the Web for an Open Society" ;
#     :maker <https://www.w3.org/People/Berners-Lee/card#i> .
#
# <http://www.w3.org/DesignIssues/Overview.html> dc:title "Design Issues for the World Wide Web" ;
#     :maker <https://www.w3.org/People/Berners-Lee/card#i> .
#
# <http://www.w3.org/People/Berners-Lee/card> a :PersonalProfileDocument ;
#     cc:license <http://creativecommons.org/licenses/by-nc/3.0/> ;
#     dc:title "Tim Berners-Lee's FOAF file" ;
#     :maker <https://www.w3.org/People/Berners-Lee/card#i> ;
#     :primaryTopic <https://www.w3.org/People/Berners-Lee/card#i> .
#
# <http://www.w3.org/People/Berners-Lee/card#i> cert:key [ a cert:RSAPublicKey ;
#             cert:exponent 65537 ;
#             cert:modulus "..."^^xsd:hexBinary ] .
#
# <http://www.w3.org/data#W3C> :member <https://www.w3.org/People/Berners-Lee/card#i> .
#
# <http://dig.csail.mit.edu/breadcrumbs/blog/4> dc:title "timbl's blog on DIG" ;
#     rdfs:seeAlso <http://dig.csail.mit.edu/breadcrumbs/blog/feed/4> ;
#     :maker <https://www.w3.org/People/Berners-Lee/card#i> .
#
# <https://timbl.com/timbl/Public/friends.ttl> a :PersonalProfileDocument ;
#     cc:license <http://creativecommons.org/licenses/by-nc/3.0/> ;
#     dc:title "Tim Berners-Lee's editable profile" ;
#     :maker <https://www.w3.org/People/Berners-Lee/card#i> ;
#     :primaryTopic <https://www.w3.org/People/Berners-Lee/card#i> .
#
# <https://www.w3.org/People/Berners-Lee/card#i> a con:Male,
#         :Person ;
#     rdfs:label "Tim Berners-Lee" ;
#     sioc:avatar <http://www.w3.org/People/Berners-Lee/images/timbl-image-by-Coz-cropped.jpg> ;
#     schema:owns <https://timblbot.inrupt.net/profile/card#me> ;
#     rdfs:seeAlso <https://timbl.com/timbl/Public/friends.ttl> ;
#     con:assistant <https://www.w3.org/People/Berners-Lee/card#amy> ;
#     con:homePage <http://www.w3.org/People/Berners-Lee/> ;
#     con:office [ con:address [ con:city "Cambridge" ;
#                     con:country "USA" ;
#                     con:postalCode "02139" ;
#                     con:street "32 Vassar Street" ;
#                     con:street2 "MIT CSAIL Building 32" ] ;
#             geo:location [ geo:lat "42.361860" ;
#                     geo:long "-71.091840" ] ] ;
#     con:preferredURI "https://www.w3.org/People/Berners-Lee/card#i" ;
#     con:publicHomePage <http://www.w3.org/People/Berners-Lee/> ;
#     vcard:fn "Tim Berners-Lee" ;
#     vcard:hasAddress [ a vcard:Work ;
#             vcard:locality "Cambridge" ;
#             vcard:postal-code "02139" ;
#             vcard:region "MA" ;
#             vcard:street-address "32 Vassar Street" ] ;
#     ldp:inbox <https://timbl.com/timbl/Public/Inbox> ;
#     space:preferencesFile <https://timbl.com/timbl/Data/preferences.n3> ;
#     space:storage <https://timbl.com/timbl/Public/>,
#         <https://timbl.inrupt.net/>,
#         <https://timbl.solid.community/> ;
#     solid:editableProfile <https://timbl.com/timbl/Public/friends.ttl> ;
#     solid:oidcIssuer <https://timbl.com> ;
#     solid:profileBackgroundColor "#ffffff" ;
#     solid:profileHighlightColor "#00467E" ;
#     solid:publicTypeIndex <https://timbl.com/timbl/Public/PublicTypeIndex.ttl> ;
#     :account <http://en.wikipedia.org/wiki/User:Timbl>,
#         <http://twitter.com/timberners_lee>,
#         <http://www.reddit.com/user/timbl/> ;
#     :based_near [ geo:lat "42.361860" ;
#             geo:long "-71.091840" ] ;
#     :family_name "Berners-Lee" ;
#     :givenname "Timothy" ;
#     :homepage <https://www.w3.org/People/Berners-Lee/> ;
#     :img <https://www.w3.org/Press/Stock/Berners-Lee/2001-europaeum-eighth.jpg> ;
#     :mbox <mailto:timbl@w3.org> ;
#     :mbox_sha1sum "965c47c5a70db7407210cef6e4e6f5374a525c5c" ;
#     :name "Timothy Berners-Lee" ;
#     :nick "TimBL",
#         "timbl" ;
#     :openid <https://www.w3.org/People/Berners-Lee/> ;
#     :title "Sir" ;
#     :weblog <http://dig.csail.mit.edu/breadcrumbs/blog/4> ;
#     :workplaceHomepage <https://www.w3.org/> .

# %% [markdown]
# ### We will use [schema](https://schema.org/) to define our Golden Age graph. First, we define our graph (g)

# %%
import rdflib
from rdflib import Graph, Literal, RDF, URIRef
# rdflib knows about some namespaces, like FOAF
from rdflib.namespace import FOAF , XSD
from rdflib import Namespace

# create a Graph
g = rdflib.Graph()

SDO = Namespace("https://schema.org/")

g.bind("schema", SDO)

# create a Graph
g = Graph()

g.namespace_manager.bind('schema', SDO, override=False)

# %% [markdown]
# ### Accessing Rijksmuseum
# Now, we will describe the authors by means of schema and their works. First, we will retrieve the paintings from the Rijksmuseum.
#
# We will use the Rijksmuseum API to retrieve paintings of the Dutch Golden Age authors in our list retrieved from Wikidata. We will creative URLs using the name of the author. For instance,
# https://www.rijksmuseum.nl/api/nl/collection?key=XXXXX&involvedMaker=David+van+der+Plas

# %%
import requests 
import json

for index, row in ga_df.loc[ga_df['periodLabel.value'] == 'Dutch Golden Age painting'].iterrows():
    print(row['itemLabel.value'])
    
    idWikidata = str(row['item.value'].replace('http://www.wikidata.org/entity/',''))
    
    person = URIRef("http://example.org/person/" + idWikidata)
    g.add((person, RDF.type, SDO.Person))
    g.add((person, RDF.type, FOAF.Person))
    g.add((person, FOAF.name, Literal(row['itemLabel.value'])))
    g.add((person, SDO.identifier, Literal(idWikidata)))
    g.add((person, SDO.sameAs, URIRef(row['item.value'])))
    g.add((person, SDO.sameAs, URIRef('https://viaf.org/viaf/' + str(row['viaf.value']))))
    
    # Making a get request 
    response = requests.get('https://www.rijksmuseum.nl/api/nl/collection?key=' + rijks_key + '&involvedMaker=' + row['itemLabel.value']) 
  
    data = response.json()
    for p in data['artObjects']:
        print(p)
        
        work = URIRef("http://example.org/work/ri-" + str(p['id']))
        
        # Add triples using store's add() method.
        g.add((work, RDF.type, SDO.CreativeWork))
        g.add((work, RDF.type, SDO.Painting))
        g.add((work, SDO.creator, person))
        
        g.add((work, SDO.name, Literal(p['title'], lang="nl")))
        g.add((work, SDO.name, Literal(p['longTitle'], lang="nl")))
        g.add((work, SDO.identifier, Literal(p['id'])))
        g.add((work, SDO.maintainer, URIRef('https://www.rijksmuseum.nl/')))
        g.add((work, SDO.license, URIRef('https://www.rijksmuseum.nl/en/data/policy')))
        if p['webImage'] and p['webImage']['width'] :
            #print(p['webImage']['width'])
            g.add((work, SDO.width, Literal(p['webImage']['width'])))
        if p['webImage'] and p['webImage']['height'] :    
            #print(p['webImage']['height'])
            g.add((work, SDO.height, Literal(p['webImage']['height'])))
        if p['webImage'] and p['webImage']['url'] :    
            #print(p['webImage']['url'])
            g.add((work, SDO.image, URIRef(p['webImage']['url'])))
        for loc in p['productionPlaces']:    
            g.add((work, SDO.locationCreated, Literal(loc, lang="nl")))
# Out:
# Jan van Gool
# {'links': {'self': 'http://www.rijksmuseum.nl/api/nl/collection/RP-T-1936-9', 'web': 'http://www.rijksmuseum.nl/nl/collectie/RP-T-1936-9'}, 'id': 'nl-RP-T-1936-9', 'objectNumber': 'RP-T-1936-9', 'title': 'Varkens en ezels onder bomen', 'hasImage': True, 'principalOrFirstMaker': 'Jan van Gool', 'longTitle': 'Varkens en ezels onder bomen, Jan van Gool, 1695 - 1763', 'showImage': True, 'permitDownload': True, 'webImage': {'guid': '0ac159bb-411e-467d-b28b-bb059c7f729f', 'offsetPercentageX': 0, 'offsetPercentageY': 0, 'width': 2500, 'height': 1999, 'url': 'https://lh3.ggpht.com/jBIY-EdweVTGo0e77ivQjhSxed4WmQF52y8Yt37dqVnOzEdt6rrAk5T0xm9z1LNqZUr_abavJLVlOq7D8idlxLlqNzA=s0'}, 'headerImage': {'guid': '7c49dd01-df44-480a-bb65-9b71bda01eb4', 'offsetPercentageX': 0, 'offsetPercentageY': 0, 'width': 1920, 'height': 460, 'url': 'https://lh4.ggpht.com/kccjmSl_rqGu99GmQu83eEg2o2AyhtJECi6XWJvMx7Qi1UpWdGpxdVJBZviPb7Vlaf9hAyAucbx6tyRDjA8uEmXRU0GW=s0'}, 'productionPlaces': []}
# 2500
# 1999
# https://lh3.ggpht.com/jBIY-EdweVTGo0e77ivQjhSxed4WmQF52y8Yt37dqVnOzEdt6rrAk5T0xm9z1LNqZUr_abavJLVlOq7D8idlxLlqNzA=s0
# {'links': {'self': 'http://www.rijksmuseum.nl/api/nl/collection/RP-T-1893-A-2756', 'web': 'http://www.rijksmuseum.nl/nl/collectie/RP-T-1893-A-2756'}, 'id': 'nl-RP-T-1893-A-2756', 'objectNumber': 'RP-T-1893-A-2756', 'title': 'Landschap met vee', 'hasImage': True, 'principalOrFirstMaker': 'Jan van Gool', 'longTitle': 'Landschap met vee, Jan van Gool, 1756', 'showImage': True, 'permitDownload': True, 'webImage': {'guid':
 'web': 'http://www.rijksmuseum.nl/nl/collectie/SK-C-133'}, 'id': 'nl-SK-C-133', 'objectNumber': 'SK-C-133', 'title': 'Arcadisch landschap met herders en vee', 'hasImage': True, 'principalOrFirstMaker': 'Jan van Gool', 'longTitle': 'Arcadisch landschap met herders en vee, Jan van Gool, 1710 - 1763', 'showImage': True, 'permitDownload': True, 'webImage': {'guid': '0a2288ea-1d95-4f36-b9ec-9a0391d3a258', 'offsetPercentageX': 0, 'offsetPercentageY': 0, 'width': 2000, 'height': 1319, 'url': 'https://lh3.ggpht.com/s35vX3vM1HO2OGjhB_Y3gkfV8xlan2KW5dBgQX9pdPbIwa8LtPYQaEixP8-UOiD9Zrm2J1398kzN-gc4M7JgcRcEWpg=s0'}, 'headerImage': {'guid': '59702048-5eb8-4289-9a81-07a890715478', 'offsetPercentageX': 0, 'offsetPercentageY': 0, 'width': 1920, 'height': 460, 'url': 'https://lh4.ggpht.com/O9x_FwzjucNy58ywj3LR91-_CeDMN83ANegWZGePuhO3LjxgZM1_561ChpazaQy_eOUa8oVyABNHvF6ff_lw4u-FQQ=s0'}, 'productionPlaces': []}
# 2000
# 1319
# https://lh3.ggpht.com/s35vX3vM1HO2OGjhB_Y3gkfV8xlan2KW5dBgQX9pdPbIwa8LtPYQaEixP8-UOiD9Zrm2J1398kzN-gc4M7JgcRcEWpg=s0
# {'links': {'self': 'http://www.rijksmuseum.nl/api/nl/collection/RP-P-2004-75-20', 'web': 'http://www.rijksmuseum.nl/nl/collectie/RP-P-2004-75-20'}, 'id': 'nl-RP-P-2004-75-20', 'objectNumber': 'RP-P-2004-75-20', 'title': 'Portret van Cornelis Troost en Gerard Melder', 'hasImage': False, 'principalOrFirstMaker': 'Pieter Tanjé', 'longTitle': 'Portret van Cornelis Troost en Gerard Melder, Pieter Tanjé, 1750', 'showImage': False, 'permitDownload': True, 'webImage': None, 'headerImage': {'guid': None, 'offsetPercentageX': 0, 'offsetPercentageY': 0, 'width': 0, 'height': 0, 'url': None}, 'productionPlaces': ['Den Haag']}
# {'links': {'self': 'http://www.rijksmuseum.nl/api/nl/collection/RP-P-OB-28.014', 'web': 'http://www.rijksmuseum.nl/nl/collectie/RP-P-OB-28.014'}, 'id': 'nl-RP-P-OB-28.014', 'objectNumber': 'RP-P-OB-28.014', 'title': 'Hond en schapen', 'hasImage': True, 'principalOrFirstMaker': 'Roelof van der Meulen', 'longTitle': 'Hond en schapen, Roelof van der Meulen, 1820 - 1833', 'showImage': True, 'permitDownload': True, 'webImage': {'guid': '6b0589a9-1f65-4255-a036-9a3b7a97266b', 'offsetPercentageX': 0, 'offsetPercentageY': 0, 'width': 1826, 'height': 2500, 'url': 'https://lh3.googleusercontent.com/XhD4sEX_ZdhVCM0thcDwprbvKBmxSdNB2Nx2c1sjEncUFvAACusQf38zryldLW01XpBhReH_enewlelbmueeH4OuNZJr=s0'}, 'headerImage': {'guid': 'b6f74ee2-9dd8-45f9-a6b4-2011bdb71a27', 'offsetPercentageX': 0, 'offsetPercentageY': 0, 'width': 1826, 'height': 438, 'url': 'https://lh3.googleusercontent.com/UA0VonVNpfCbLSnZUHJ7f81PRXRuUqZygddsn6DuGUEXArokXCszftNPaU3nyDXH8VPP0apylZGQZu2qYeOY4X0c0g=s0'}, 'productionPlaces': ['Amsterdam', 'Nederland', 'Amsterdam']}
# 1826
# 2500
# https://lh3.googleusercontent.com/XhD4sEX_ZdhVCM0thcDwprbvKBmxSdNB2Nx2c1sjEncUFvAACusQf38zryldLW01XpBhReH_enewlelbmueeH4OuNZJr=s0
# {'links': {'self': 'http://www.rijksmuseum.nl/api/nl/collection/RP-P-1940-652', 'web': 'http://www.rijksmuseum.nl/nl/collectie/RP-P-1940-652'}, 'id': 'nl-RP-P-1940-652', 'objectNumber': 'RP-P-1940-652', 'title': 'Portretten van Jacob Appel, Dirk Dalens en Jan Wandelaar', 'hasImage': False, 'principalOrFirstMaker': 'Pieter Tanjé', 'longTitle': 'Portretten van Jacob Appel, Dirk Dalens en Jan Wandelaar, Pieter Tanjé, 1751', 'showImage': False, 'permitDownload': True, 'webImage': None, 'headerImage': {'guid': None, 'offsetPercentageX': 0, 'offsetPercentageY': 0, 'width':
 'offsetPercentageX': 0, 'offsetPercentageY': 0, 'width': 2500, 'height': 2060, 'url': 'https://lh4.ggpht.com/89GiWHR_D_VRTUpuWrovVDCvge1hPFcH1fZIrLlDdk9muw41TFY2wuvsmpFLoPo6j8TLCJr6ID4aT9MyVXemY1f35R8=s0'}, 'headerImage': {'guid': '6aea9f51-6615-4992-a6b4-1c26abe6481d', 'offsetPercentageX': 0, 'offsetPercentageY': 0, 'width': 1920, 'height': 460, 'url': 'https://lh3.ggpht.com/sfiEOBfla3OKBff0PO3DnGEhVv_l6bGleYWQWjeF2vlwsswjOszZN5IXhvIDDTyNm6EBKsT3qDfTnNNHvbqqoM8EbayL=s0'}, 'productionPlaces': []}
# 2500
# 2060
# https://lh4.ggpht.com/89GiWHR_D_VRTUpuWrovVDCvge1hPFcH1fZIrLlDdk9muw41TFY2wuvsmpFLoPo6j8TLCJr6ID4aT9MyVXemY1f35R8=s0
# {'links': {'self': 'http://www.rijksmuseum.nl/api/nl/collection/RP-P-OB-46.476', 'web': 'http://www.rijksmuseum.nl/nl/collectie/RP-P-OB-46.476'}, 'id': 'nl-RP-P-OB-46.476', 'objectNumber': 'RP-P-OB-46.476', 'title': 'Kudde dieren bij een drinkplaats', 'hasImage': True, 'principalOrFirstMaker': 'Govert van der Leeuw', 'longTitle': 'Kudde dieren bij een drinkplaats, Govert van der Leeuw, 1655 - 1688', 'showImage': True, 'permitDownload': True, 'webImage': {'guid': 'f8bf6637-c5e3-476c-ab91-6170cc00857b', 'offsetPercentageX': 0, 'offsetPercentageY': 0, 'width': 2500, 'height': 1889, 'url': 'https://lh4.ggpht.com/FrD8QnYiorPrVF7IUSubs2SMY61wWiN-t4YgJY8ynVm-29Hjn5M6DL9wlp1l0aqVB7FeSYwDc7VIL3Q6G68TaOzyQA=s0'}, 'headerImage': {'guid': '6231dfa2-20e9-4267-ac07-95295eca5fea', 'offsetPercentageX': 0, 'offsetPercentageY': 0, 'width': 1920, 'height': 460, 'url': 'https://lh6.ggpht.com/S3dG4_zzAIH1J2aIT9umGLdDLM2b47mwzwIbKoEgd92szWEwdUMVmC5TexrvHiMHPSaleY2UWXTCaEjpP5q3HP02rA=s0'}, 'productionPlaces': []}
# 2500
# 1889
# https://lh4.ggpht.com/FrD8QnYiorPrVF7IUSubs2SMY61wWiN-t4YgJY8ynVm-29Hjn5M6DL9wlp1l0aqVB7FeSYwDc7VIL3Q6G68TaOzyQA=s0

# %% [markdown]
# ### Let's see the result

# %%
print(g.serialize(format='n3').decode("utf-8"))
# Out:
# @prefix ns1: <http://xmlns.com/foaf/0.1/> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix schema: <https://schema.org/> .
# @prefix xml: <http://www.w3.org/XML/1998/namespace> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# <http://example.org/person/Q1296941> a ns1:Person,
#         schema:Person ;
#     ns1:name "Egbert van der Poel" ;
#     schema:identifier "Q1296941" ;
#     schema:sameAs <http://www.wikidata.org/entity/Q1296941>,
#         <https://viaf.org/viaf/37188512> .
#
# <http://example.org/person/Q17343011> a ns1:Person,
#         schema:Person ;
#     ns1:name "Jacob de Gheyn III" ;
#     schema:identifier "Q17343011" ;
#     schema:sameAs <http://www.wikidata.org/entity/Q17343011>,
#         <https://viaf.org/viaf/60611905> .
#
# <http://example.org/person/Q205863> a ns1:Person,
#         schema:Person ;
#     ns1:name "Jan Steen" ;
#     schema:identifier "Q205863" ;
#     schema:sameAs <http://www.wikidata.org/entity/Q205863>,
#         <https://viaf.org/viaf/15041897> .
#
# <http://example.org/person/Q2359229> a ns1:Person,
#         schema:Person ;
#     ns1:name "Jan Albertsz Rotius" ;
#     schema:identifier "Q2359229" ;
#     schema:sameAs <http://www.wikidata.org/entity/Q2359229>,
#         <https://viaf.org/viaf/95736294> .
#
# <http://example.org/person/Q2581805> a ns1:Person,
#         schema:Person ;
#     ns1:name "Jacob Rotius" ;
#     schema:identifier "Q2581805" ;
#     schema:sameAs <http://www.wikidata.org/entity/Q2581805>,
#         <https://viaf.org/viaf/95771549> .
#
# <http://example.org/person/Q3313485> a ns1:Person,
#         schema:Person ;
#     ns1:name "Hans Jordaens" ;
#     schema:identifier "Q3313485" ;
#     schema:sameAs <http://www.wikidata.org/entity/Q3313485>,
#         <https://viaf.org/viaf/95687660> .
#
# <http://example.org/person/Q335927> a ns1:Person,
#         schema:Person ;
#     ns1:name "Gerrit Dou" ;
#     schema:identifier "Q335927" ;
#     schema:sameAs <http://www.wikidata.org/entity/Q335927>,
#         <https://viaf.org/viaf/96538660> .
#
# <http://example.org/person/Q348688> a ns1:Person,
#         schema:Person ;
#     ns1:name "Pieter Leermans" ;
#     schema:identifier "Q348688" ;
#     schema:sameAs <http://www.wikidata.org/entity/Q348688>,
#         <https://viaf.org/viaf/80992813> .
#
# <http://example.org/person/Q354832> a ns1:Person,
#         schema:Person ;
#     ns1:name "Pieter Claesz" ;
#     schema:identifier "Q354832" ;
#     schema:sameAs <http://www.wikidata.org/entity/Q354832>,
#         <https://viaf.org/viaf/47843985> .
#
# <http://example.org/person/Q3806961> a ns1:Person,
#         schema:Person ;
#     ns1:name "Johannes van Haensbergen" ;
#     schema:identifier "Q3806961" ;
#     schema:sameAs <http://www.wikidata.org/entity/Q3806961>,
#         <https://viaf.org/viaf/95853316> .
#
# <http://example.org/person/Q5598> a ns1:Person,
#         schema:Person ;
#     ns1:name "Rembrandt" ;
#     schema:identifier "Q5598" ;
#     schema:sameAs <http://www.wikidata.org/entity/Q5598>,
#         <https://viaf.org/viaf/64013650> .
#
# <http://example.org/person/Q576009> a ns1:Person,
#         schema:Person ;
#     ns1:name "Jacobus Mancadan" ;
#     schema:identifier "Q576009" ;
#     schema:sameAs <http://www.wikidata.org/entity/Q576009>,
#         <https://viaf.org/viaf/67398457> .
#
# <http://example.org/person/Q7192819> a ns1:Person,
#         schema:Person ;
#     ns1:name "Pieter Pietersz Nedek" ;
#     schema:identifier "Q7192819" ;
#     schema:sameAs <http://www.wikidata.org/entity/Q7192819>,
#         <https://viaf.org/viaf/96259669> .
#
# <http://example.org/person/Q719666> a ns1:Person,
#         schema:Person ;
#     ns1:name "Karel Dujardin" ;
#     schema:identifier "Q719666" ;
#     schema:sameAs <http://www.wikidata.org/entity/Q719666>,
#         <https://viaf.org/viaf/305405831> .
#
# <http://example.org/person/Q798827> a ns1:Person,
#         schema:Person ;
#     ns1:name "Lambert Jacobsz" ;
#     schema:identifier "Q798827" ;
#     schema:sameAs <http://www.wikidata.org/entity/Q798827>,
#         <https://viaf.org/viaf/294574511> .
#
# <http://example.org/person/Q978437> a ns1:Person,
#         schema:Person ;
#     ns1:name "Gerard Hoet" ;
#     schema:identifier "Q978437" ;
#     schema:sameAs <http://www.wikidata.org/entity/Q978437>,
#         <https://viaf.org/viaf/69200941> .
#
# <http://example.org/work/ri-nl-RP-F-2001-7-1734-1> a schema:CreativeWork,
#         schema:Painting ;
#     schema:creator <http://example.org/person/Q759747> ;
#     schema:identifier "nl-RP-F-2001-7-1734-1" ;
#     schema:license <https://www.rijksmuseum.nl/en/data/policy> ;
#     schema:maintainer <https://www.rijksmuseum.nl/> ;
#     schema:name "Fotoreproductie van een schilderij van een stilleven met dode vogels door Evert van Aelst"@nl,
#         "Fotoreproductie van een schilderij van een stilleven met dode vogels door Evert van Aelst, Alexandre (fotograaf), ca. 1879 - in of voor 1884"@nl .
#
# <http://example.org/work/ri-nl-RP-P-1878-A-1058> a schema:CreativeWork,
#         schema:Painting ;
#     schema:creator <http://example.org/person/Q759784> ;
#     schema:height 2500 ;
#     schema:identifier "nl-RP-P-1878-A-1058" ;
#     schema:image <https://lh4.ggpht.com/GmMvnVHBaWhKwUklBfW03Bnhp2fOj3J8v0ZiWeODw7p2zTfaYAskwvwQsGGZz9QehQU3o3Qv6S9nHIyzJKstuWTNYk4v=s0> ;
#     schema:license <https://www.rijksmuseum.nl/en/data/policy> ;
#     schema:locationCreated "Dordrecht"@nl ;
#     schema:maintainer <https://www.rijksmuseum.nl/> ;
#     schema:name "Portret van Jacob Sasbout Souburg"@nl,
#         "Portret van Jacob Sasbout Souburg, Arnold Houbraken, 1670 - 1694"@nl ;
#     schema:width 1768 .
#
# <http://example.org/work/ri-nl-RP-P-1878-A-1543> a schema:CreativeWork,
#         schema:Painting ;
#     schema:creator <http://example.org/person/Q142710> ;
#     schema:height 1804 ;
#     schema:identifier "nl-RP-P-1878-A-1543" ;
#     schema:image <https://lh6.ggpht.com/pOHR7jAwaigESpZ2TSH9t2dkcE1VEypoSVJBq82eOF4YAPuQ1ZDcGjtin8ZPujnVIzxHJMwCHHBjhboKmtyRKTvenErB=s0> ;
#     schema:license <https://www.rijksmuseum.nl/en/data/policy> ;
#     schema:locationCreated "? Nederland"@nl ;
#     schema:maintainer <https://www.rijksmuseum.nl/> ;
#     schema:name "Knoestige bomen aan het water"@nl,
#         "Knoestige bomen aan het water, Roelant Savery, 1605 - 1639"@nl ;
#     schema:width 2148 .
#
# <http://example.org/work/ri-nl-RP-P-1878-A-2481> a schema:CreativeWork,
#         schema:Painting ;
#     schema:creator <http://example.org/person/Q380704> ;
#     schema:identifier "nl-RP-P-1878-A-2481" ;
#     schema:license <https://www.rijksmuseum.nl/en/data/policy> ;
#     schema:maintainer <https://www.rijksmuseum.nl/> ;
#     schema:name "De Schuttersmaaltijd van 1648 naar B. van der Helst; onafgewerkten staat"@nl,
#         "De Schuttersmaaltijd van 1648 naar B. van der Helst; onafgewerkten staat, Johann Wilhelm Kaiser (I), 1849"@nl .
#
# <http://example.org/work/ri-nl-RP-P-1882-A-6717> a schema:CreativeWork,
#         schema:Painting ;
#     schema:creator <http://example.org/person/Q41264> ;
#     schema:height 2500 ;
#     schema:identifier "nl-RP-P-1882-A-6717" ;
#     schema:image <https://lh5.ggpht.com/iiTo2qHj8U5EvwLsnUeJpEqSypFnVRgipAhzND7GxbaMdHURNAG-xyeGqUzHF4L6CmQEpe7VtlTtfJmp3obdMamfqQ=s0> ;
#     schema:license <https://www.rijksmuseum.nl/en/data/policy> ;
#     schema:locationCreated "Amsterdam"@nl,
#         "Delft"@nl ;
#     schema:maintainer <https://www.rijksmuseum.nl/> ;
#     schema:name "Het melkmeisje"@nl,
#         "Het melkmeisje, Jurriaan Cootwijck, 1724 - 1798"@nl ;
#     schema:width 1958 .
#
# <http://example.org/work/ri-nl-RP-P-1882-A-6718> a schema:CreativeWork,
#         schema:Painting ;
#     schema:creator <http://example.org/person/Q41264> ;
#     schema:height 2500 ;
#     schema:identifier "nl-RP-P-1882-A-6718" ;
#     schema:image <https://lh3.ggpht.com/2Yf1qnx0lD6HN8ewwgXQ8xkUwrt4vYp3X-xIY1971MlC4gyGkMD0kTJTa97daifB4YvTkdeQXiVOYyD_XT6EhdOtphQ=s0> ;
#     schema:license <https://www.rijksmuseum.nl/en/data/policy> ;
#     schema:locationCreated "Amsterdam"@nl,
#         "Delft"@nl ;
#     schema:maintainer <https://www.rijksmuseum.nl/> ;
#     schema:name "Keukenmeid met tobbe"@nl,
#         "Keukenmeid met tobbe, Jurriaan Cootwijck, 1724 - 1798"@nl ;
#     schema:width 1866 .
#
# <http://example.org/work/ri-nl-RP-P-1882-A-6778> a schema:CreativeWork,
#         schema:Painting ;
#     schema:creator <http://example.org/person/Q41264> ;
#     schema:height 2500 ;
#     schema:identifier "nl-RP-P-1882-A-6778" ;
#     schema:image <https://lh5.ggpht.com/bO8t3EH-hFIimiueuu7zUX6CG4Zo-gZvOPt8Q3TuKT_s96R0p1A3tf4mgAZ2RPEaTJ_ivoei12c_guBhoU8WvYeFFfM=s0> ;
#     schema:license <https://www.rijksmuseum.nl/en/data/policy> ;
#     schema:locationCreated "Amsterdam"@nl,
#         "Delft"@nl ;
#     schema:maintainer <https://www.rijksmuseum.nl/> ;
#     schema:name "Het melkmeisje"@nl,
#         "Het melkmeisje, Jurriaan Cootwijck, 1724 - 1798"@nl ;
#     schema:width 1891 .
#
# <http://example.org/work/ri-nl-RP-P-1882-A-6779> a schema:CreativeWork,
#         schema:Painting ;
#     schema:creator <http://example.org/person/Q41264> ;
#     schema:height 2500 ;
#     schema:identifier "nl-RP-P-1882-A-6779" ;
#     schema:image <https://lh4.ggpht.com/DGPVDBA8pV2UglUZkl6VzeH8a5x3nNDORZ4caUzo1Sp1bmx9j1nKavCcPwVPnztR27D60DWKSK9SkGhiW9pKWvi__78=s0> ;
#     schema:license <https://www.rijksmuseum.nl/en/data/policy> ;
#     schema:locationCreated "Amsterdam"@nl,
#         "Delft"@nl ;
#     schema:maintainer <https://www.rijksmuseum.nl/> ;
#     schema:name "Het melkmeisje"@nl,
#         "Het melkmeisje, Jurriaan Cootwijck, 1724 - 1798"@nl ;
#     schema:width 1900 .
#
# <http://example.org/work/ri-nl-RP-P-1884-A-8021> a schema:CreativeWork,
#         schema:Painting ;
#     schema:creator <http://example.org/person/Q28144> ;
#     schema:height 2500 ;
#     schema:identifier "nl-RP-P-1884-A-8021" ;
#     schema:image <https://lh4.ggpht.com/OdqzXwWcsN8WQaZDh-lZhVGTi2JzJauPvSZCpnb1wA6hDx-evkmj-YoJOrSQllK0w49ROdPIod9tCdscn8E5I-9vGSrH=s0> ;
#     schema:license <https://www.rijksmuseum.nl/en/data/policy> ;
#     schema:maintainer <https://www.rijksmuseum.nl/> ;
#     schema:name "Boereninterieur met geslacht varken"@nl,
#         "Boereninterieur met geslacht varken, Jacob Louys (1620-ca.1673), 1630 - 1673"@nl ;
#     schema:width 1945 .
#
# <http://example.org/work/ri-nl-RP-P-1889-A-15063> a schema:CreativeWork,
#         schema:Painting ;
#     schema:creator <http://example.org/person/Q28144> ;
#     schema:height 2500 ;
#     schema:identifier "nl-RP-P-1889-A-15063" ;
#     schema:image <https://lh6.ggpht.com/RF5fSOlk5N4pIvY9uyY3GQGPKVMIa49JYzepMy1qChfkOY7LvpfdnFv_li4PgYgBDVVnJz8ytVHRvhnJhuSTCEBpo_c=s0> ;
#     schema:license <https://www.rijksmuseum.nl/en/data/policy> ;
#     schema:maintainer <https://www.rijksmuseum.nl/> ;
#     schema:name "Boereninterieur met geslacht varken"@nl,
#         "Boereninterieur met geslacht varken, Jacob Louys (1620-ca.1673), 1630 - 1673"@nl ;
#     schema:width 2003 .
#
# <http://example.org/work/ri-nl-RP-P-1894-A-18564> a schema:CreativeWork,
#         schema:Painting ;
#     schema:creator <http://example.org/person/Q380704> ;
#     schema:height 5391 ;
#     schema:identifier "nl-RP-P-1894-A-18564" ;
#     schema:image <https://lh3.googleusercontent.com/u_KD0uLm63UwhsN2pTa4Y0VDxiA0A232lx2NGuobGW7T5PdaKswmKETIQ8_3UjKWxdu45VZHGtbEH-g8vOaGEeiU_ZA=s0> ;
#     schema:license <https://www.rijksmuseum.nl/en/data/policy> ;
#     schema:locationCreated "Amsterdam"@nl ;
#     schema:maintainer <https://www.rijksmuseum.nl/> ;
#     schema:name "Portret van Cornelis Witsen"@nl,
#         "Portret van Cornelis Witsen, Jacob Houbraken, 1796"@nl ;
#     schema:width 3652 .
#
# <http://example.org/work/ri-nl-RP-P-1904-278> a schema:CreativeWork,
#         schema:Painting ;
#     schema:creator <http://example.org/person/Q2576955> ;
#     schema:height 2622 ;
#     schema:identifier "nl-RP-P-1904-278" ;
#     schema:image <https://lh3.googleusercontent.com/o-UazUpOtVQwj0LRhmqaHdmKWFQGfAWd_kf_Fa6NNlr-3QVOTQVpp4ZvJWsqCewu_iuQxpqgLc5xzO4KYvO9y-uwHQ=s0> ;
#     schema:license <https://www.rijksmuseum.nl/en/data/policy> ;
#     schema:locationCreated "Amsterdam"@nl ;
#     schema:maintainer <https://www.rijksmuseum.nl/> ;
#     schema:name "Diane de Poitiers, afgebeeld als de godin Diana"@nl,
#         "Diane de Poitiers, afgebeeld als de godin Diana, Abraham Bloteling, 1655 - 1690"@nl ;
#     schema:width 1914 .
#
# <http://example.org/work/ri-nl-RP-P-1904-4536> a schema:CreativeWork,
#         schema:Painting ;
#     schema:creator <http://example.org/person/Q2486642> ;
#     schema:height 2500 ;
#     schema:identifier "nl-RP-P-1904-4536" ;
#     schema:image <https://lh4.ggpht.com/DKjA65XLpBXTWqcpeZlFUqTCO_LvuEi9KqUCuDFk7EI44HYXWvqIxJWoexCgV1YyBo62KAsLRjNvC2zqtnwHjil6b43f=s0> ;
#     schema:license <https://www.rijksmuseum.nl/en/data/policy> ;
#     schema:locationCreated "Amsterdam"@nl ;
#     schema:maintainer <https://www.rijksmuseum.nl/> ;
#     schema:name "Portret van Steven Blankaart"@nl,
#         "Portret van Steven Blankaart, Jacob Gole, 1670 - 1724"@nl ;
#     schema:width 1784 .
#
# <http://example.org/work/ri-nl-RP-P-1906-2926> a schema:CreativeWork,
#         schema:Painting ;
#     schema:creator <http://example.org/person/Q2486642> ;
#     schema:height 2500 ;
#     schema:identifier "nl-RP-P-1906-2926" ;
#     schema:image <https://lh4.ggpht.com/ZJ2s5n6MYGkFXJANE_IMMY7QxpOOUMAmSWwxHs5AiXokSx5p_c8nKAEWYDpJS1aDZFQT67eRTADXOaZJN3wa4pV-14s=s0> ;
#     schema:license <https://www.rijksmuseum.nl/en/data/policy> ;
#     schema:locationCreated "Nederland"@nl ;
#     schema:maintainer <https://www.rijksmuseum.nl/> ;
#     schema:name "Portret van Willem Surenhuys"@nl,
#         "Portret van Willem Surenhuys, Abraham de Blois, 1679 - 1717"@nl ;
#     schema:width 1727 .
#
# <http://example.org/work/ri-nl-RP-P-1906-3141> a schema:CreativeWork,
#         schema:Painting ;
#     schema:creator <http://example.org/person/Q167654> ;
#     schema:height 2500 ;
#     schema:identifier "nl-RP-P-1906-3141" ;
#     schema:image <https://lh6.ggpht.com/-p-VR_DQElJCeAwGrDuaiZ4TSYKeyOL2zaN-Dmo_Qe9csVb1XhONZEgCwr0S4H8L_h2LRF7ISjcDZDtnFfWn2DutVw=s0> ;
#     schema:license <https://www.rijksmuseum.nl/en/data/policy> ;
#     schema:locationCreated "Amsterdam"@nl ;
#     schema:maintainer <https://www.rijksmuseum.nl/> ;
#     schema:name "Portret van René Descartes"@nl,
#         "Portret van René Descartes, Jacob Gole, 1670 - 1724"@nl ;
#     schema:width 1793 .
#
# <http://example.org/work/ri-nl-RP-P-1906-3146> a schema:CreativeWork,
#         schema:Painting ;
#     schema:creator <http://example.org/person/Q2486642> ;
#     schema:height 2500 ;
#     schema:identifier "nl-RP-P-1906-3146" ;
#     schema:image <https://lh3.ggpht.com/EdzgmsCggI6iO6KI5VZkXQ4zqa084cXtROJafm3_SsswBv6za3M4Qv65o-PVdvPncJEtpD1bn4avLJsCQKjA_-SNRKo=s0> ;
#     schema:license <https://www.rijksmuseum.nl/en/data/policy> ;
#     schema:locationCreated "Amsterdam"@nl ;
#     schema:maintainer <https://www.rijksmuseum.nl/> ;
#     schema:name "Zelfportret van Jacob Gole"@nl,
#         "Zelfportret van Jacob Gole, Jacob Gole, 1680 - 1724"@nl ;
#     schema:width 1835 .
#
# <http://example.org/work/ri-nl-RP-P-1906-3292> a schema:CreativeWork,
#         schema:Painting ;
#     schema:creator <http://example.org/person/Q167654> ;
#     schema:height 2500 ;
#     schema:identifier "nl-RP-P-1906-3292" ;
#     schema:image <https://lh4.ggpht.com/0Zx-3eHuzo8k_KhbfFuiDfdEQGqzhPhDvHOhEKkkozzxBd491iJjJigeMBbGjneXzM2sPrW1eTchff1ZjJ28dJoWy2E=s0> ;
#     schema:license <https://www.rijksmuseum.nl/en/data/policy> ;
#     schema:locationCreated "Noordelijke Nederlanden"@nl ;
#     schema:maintainer <https://www.rijksmuseum.nl/> ;
#     schema:name "Jongen met een rommelpot"@nl,
#         "Jongen met een rommelpot, Johannes de Groot (II), 1698 - 1776"@nl ;
#     schema:width 2171 .
#
# <http://example.org/work/ri-nl-RP-P-1906-3360> a schema:CreativeWork,
#         schema:Painting ;
#     schema:creator <http://example.org/person/Q759784> ;
#     schema:height 2500 ;
#     schema:identifier "nl-RP-P-1906-3360" ;
#     schema:image <https://lh3.ggpht.com/nSlyrRXA1lbjorSEIUBdy2cOPhVUVwYeP-Ai84Xz2SwHuDIstbpqdQU-ztdXi-TcuOyH_nMI8K7TPc0xquQtHwu6cg=s0> ;
#     schema:license <https://www.rijksmuseum.nl/en/data/policy> ;
#     schema:locationCreated "Noordelijke Nederlanden"@nl ;
#     schema:maintainer <https://www.rijksmuseum.nl/> ;
#     schema:name "Portret van Cornelis de Witt"@nl,
#         "Portret van Cornelis de Witt, Cornelis A. Hellemans, 1660 - 1700"@nl ;
#     schema:width 2181 .
#
# <http://example.org/work/ri-nl-RP-P-1906-3465> a schema:CreativeWork,
#         schema:Painting ;
#     schema:creator <http://example.org/person/Q514276> ;
#     schema:height 2500 ;
#     schema:identifier "nl-RP-P-1906-3465" ;
#     schema:image <https://lh6.ggpht.com/GcV2yq_NdUxLDhJabNEOwxT3mdOWorsJDKReEtdjrxxAf3Qk2c0L8WcmRGqtVZdT-VL2rZgS4Fa_soTnCd5_FvHXrrpS=s0> ;
#     schema:license <https://www.rijksmuseum.nl/en/data/policy> ;
#     schema:locationCreated "Amsterdam"@nl,
#         "Dordrecht"@nl ;
#     schema:maintainer <https://www.rijksmuseum.nl/> ;
#     schema:name "Portret van Jan van Hoogstraten"@nl,
#         "Portret van Jan van Hoogstraten, Arnold Houbraken, 1682 - 1719"@nl ;
#     schema:width 1979 .
#
# <http://example.org/work/ri-nl-RP-P-1906-3466> a schema:CreativeWork,
#         schema:Painting ;
#     schema:creator <http://example.org/person/Q514276> ;
#     schema:height 2500 ;
#     schema:identifier "nl-RP-P-1906-3466" ;
#     schema:image <https://lh6.ggpht.com/nWe2WIWDM2O-Vq809ElBmc4PUi0fX7Rq2XPOPC9rVGv01WpLAI8toy4ssk36uP30MhdYZbU_zazeWGLv3FdSJGA83CI=s0> ;
#     schema:license <https://www.rijksmuseum.nl/en/data/policy> ;
#     schema:locationCreated "Amsterdam"@nl,
#         "Dordrecht"@nl ;
#     schema:maintainer <https://www.rijksmuseum.nl/> ;
#     schema:name "Portret van Jakob Zeeus"@nl,
#         "Portret van Jakob Zeeus, Arnold Houbraken, 1706 - 1719"@nl ;
#     schema:width 1764 .
#
# <http://example.org/work/ri-nl-RP-P-1907-2986> a schema:CreativeWork,
#         schema:Painting ;
#     schema:creator <http://example.org/person/Q759784> ;
#     schema:height 2946 ;
#     schema:identifier "nl-RP-P-1907-2986" ;
#     schema:image <https://lh5.ggpht.com/f2Z9bAWwmgOARfc8ZsC7F5MVQMsvx-U9h-Or-Vtaw-zpyxEhtP376ujpzrWn2el-f2lrOy9wzNTYB5oEyEbkJxFx9j8=s0> ;
#     schema:license <https://www.rijksmuseum.nl/en/data/policy> ;
#     schema:locationCreated "Amsterdam"@nl ;
#     schema:maintainer <https://www.rijksmuseum.nl/> ;
#     schema:name "Portret van predikant Joannes Vollenhove"@nl,
#         "Portret van predikant Joannes Vollenhove, Abraham de Blois, 1679 - 1717"@nl ;
#     schema:width 1883 .
#
# <http://example.org/work/ri-nl-RP-P-1908-2575> a schema:CreativeWork,
#         schema:Painting ;
#     schema:creator <http://example.org/person/Q41264> ;
#     schema:identifier "nl-RP-P-1908-2575" ;
#     schema:license <https://www.rijksmuseum.nl/en/data/policy> ;
#     schema:locationCreated "Den Haag"@nl,
#         "Nederland"@nl ;
#     schema:maintainer <https://www.rijksmuseum.nl/> ;
#     schema:name "Het melkmeisje"@nl,
#         "Het melkmeisje, Henri Koetser, 1908"@nl .
#
# <http://example.org/work/ri-nl-RP-P-1908-419> a schema:CreativeWork,
#         schema:Painting ;
#     schema:creator <http://example.org/person/Q2486642> ;
#     schema:height 2500 ;
#     schema:identifier "nl-RP-P-1908-419" ;
#     schema:image <https://lh3.ggpht.com/ibY8Xj37dn9-M_bjBGifozxbzLgzBAIgMvuL0pefrPYnG_0ax_tE4hV_3pu07oDJiLZLh-yTdtZ2qqNkO3QjQx8FTrE=s0> ;
#     schema:license <https://www.rijksmuseum.nl/en/data/policy> ;
#     schema:locationCreated "Amsterdam"@nl ;
#     schema:maintainer <https://www.rijksmuseum.nl/> ;
#     schema:name "Portret van Gerbrand van Leeuwen"@nl,
#         "Portret van Gerbrand van Leeuwen, Pieter van der Plas (II), 1687 - 1708"@nl ;
#     schema:width 1865 .
#
# <http://example.org/work/ri-nl-RP-P-1908-420> a schema:CreativeWork,
#         schema:Painting ;
#     schema:creator <http://example.org/person/Q2486642> ;
#     schema:height 2500 ;
#     schema:identifier "nl-RP-P-1908-420" ;
#     schema:image <https://lh5.ggpht.com/3ijNXJHuiXjGbcvmsLFfnZKQ4XUrC28nPqqIUsaxG8IGeNTpzNElA7Xu_0G8ZZSz4GG3EHhbkv5yN6MveQb28vS42KQ=s0> ;
#     schema:license <https://www.rijksmuseum.nl/en/data/policy> ;
#     schema:locationCreated "Amsterdam"@nl ;
#     schema:maintainer <https://www.rijksmuseum.nl/> ;
#     schema:name "Portret van Gerbrand van Leeuwen"@nl,
#         "Portret van Gerbrand van Leeuwen, Pieter van der Plas (II), 1687 - 1708"@nl ;
#     schema:width 1896 .
#
# <http://example.org/work/ri-nl-RP-P-1909-150> a schema:CreativeWork,
#         schema:Painting ;
#     schema:creator <http://example.org/person/Q167654> ;
#     schema:height 2500 ;
#     schema:identifier "nl-RP-P-1909-150" ;
#     schema:image <https://lh3.ggpht.com/9AU45cv6eEh89TieXwI0vSt0TZ-qE6s6sgZcTmRa2Yj6DyT4qHSXYzHXNA2yDEN2pPTMXqwROfRyGIUMH7IPzoH6ZKY=s0> ;
#     schema:license <https://www.rijksmuseum.nl/en/data/policy> ;
#     schema:maintainer <https://www.rijksmuseum.nl/> ;
#     schema:name "Rommelpotspeler"@nl,
#         "Rommelpotspeler, Jan van Somer, 1655 - 1700"@nl ;
#     schema:width 1874 .
#
# <http://example.org/work/ri-nl-RP-P-1911-184> a schema:CreativeWork,
#         schema:Painting ;
#     schema:creator <http://example.org/person/Q514276> ;
#     schema:height 2500 ;
#     schema:identifier "nl-RP-P-1911-184" ;
#     schema:image <https://lh4.ggpht.com/BIvHIGbksdNN0L7YwwAS0tR3qCKj6kZ5oX2FDVyFUjPd_Rcjl2oe8b6zdKoA2ed0FAUPbZ0qGlG0XH6tLYPAFZeSJ1k=s0> ;
#     schema:license <https://www.rijksmuseum.nl/en/data/policy> ;
#     schema:locationCreated "Amsterdam"@nl,
#         "Delft"@nl ;
#     schema:maintainer <https://www.rijksmuseum.nl/> ;
#     schema:name "Portret van Jacob Moelaert"@nl,
#         "Portret van Jacob Moelaert, Nicolaas Verkolje, 1683 - 1746"@nl ;
#     schema:width 1897 .
#
# <http://example.org/work/ri-nl-RP-P-1935-209> a schema:CreativeWork,
#         schema:Painting ;
#     schema:creator <http://example.org/person/Q2046773> ;
#     schema:height 1908 ;
#     schema:identifier "nl-RP-P-1935-209" ;
#     schema:image <https://lh3.ggpht.com/nDe2XIguyumT8lBzJkzGYP-o4vTWwHDCIxUs6A0wmFdMshhPjHEknJQ5zUKPIIo-Bvd5nm1hI_Vo8-gAye_p6xuCCXg=s0> ;
#     schema:license <https://www.rijksmuseum.nl/en/data/policy> ;
#     schema:maintainer <https://www.rijksmuseum.nl/> ;
#     schema:name "Verkondiging aan de herders"@nl,
#         "Verkondiging aan de herders, Govert van der Leeuw, ca. 1680"@nl ;
#     schema:width 2500 .
#
# <http://example.org/work/ri-nl-RP-P-1936-178> a schema:CreativeWork,
#         schema:Painting ;
#     schema:creator <http://example.org/person/Q709404> ;
#     schema:height 2117 ;
#     schema:identifier "nl-RP-P-1936-178" ;
#     schema:image <https://lh6.ggpht.com/GmgW8S739XkbSjQbPzdW23kalwjd-RjhLoYAZuVAiYPLjt5MkUQxj8fZ1VuI20Wq0gsvWVKc_3gy22DJAx_uOZwAIqU=s0> ;
#     schema:license <https://www.rijksmuseum.nl/en/data/policy> ;
#     schema:locationCreated "Haarlem"@nl,
#         "Leiden"@nl ;
#     schema:maintainer <https://www.rijksmuseum.nl/> ;
#     schema:name "Binnenplaats met trap"@nl,
#         "Binnenplaats met trap, Jacobus Ludovicus Cornet, 1851"@nl ;
#     schema:width 2500 .
#
# <http://example.org/work/ri-nl-RP-P-1936-353> a schema:CreativeWork,
#         schema:Painting ;
#     schema:creator <http://example.org/person/Q2576955> ;
#     schema:height 2500 ;
#     schema:identifier "nl-RP-P-1936-353" ;
#     schema:image <https://lh6.ggpht.com/eFXZuBaYd7l_1wjtdRdZddbcm4hnIhBT2Q2iO4ZseniF3LVYU8_vCceYt9OlxFa-zcArjxPdFtKCcFG-naxkiag4sio=s0> ;
#     schema:license <https://www.rijksmuseum.nl/en/data/policy> ;
#     schema:maintainer <https://www.rijksmuseum.nl/> ;
#     schema:name "Portret van Johannes Wtenbogaert"@nl,
#         "Portret van Johannes Wtenbogaert, Jacob van Loo, 1624 - 1670"@nl ;
#     schema:width 1815 .
#
# <http://example.org/work/ri-nl-RP-P-1936-403> a schema:CreativeWork,
#         schema:Painting ;
#     schema:creator <http://example.org/person/Q2046773> ;
#     schema:height 2101 ;
#     schema:identifier "nl-RP-P-1936-403" ;
#     schema:image <https://lh6.ggpht.com/tPBQa6JjUi1VZx24FJZ2PeicavWDz8cBiGbdR6ABL0kIXwRwtZpFnMZS3HAftsW_oSGNGUVi6e-c2uLSQ2GdEJS0YoA=s0> ;
#     schema:license <https://www.rijksmuseum.nl/en/data/policy> ;
#     schema:maintainer <https://www.rijksmuseum.nl/> ;
#     schema:name "Ram"@nl,
#         "Ram, Govert van der Leeuw, 1655 - 1688"@nl ;
#     schema:width 2500 .
#
# <http://example.org/work/ri-nl-RP-P-1937-1119> a schema:CreativeWork,
#         schema:Painting ;
#     schema:creator <http://example.org/person/Q380704> ;
#     schema:height 2500 ;
#     schema:identifier "nl-RP-P-1937-1119" ;
#     schema:image <https://lh4.ggpht.com/PT0k4NWfN-LWoei9GdSJcUquvTlmLq8WFoy3PDEkWSHqxscw3T-SFXx-iJI9WSR3on_cYfWeT8e-JGtqi_pV0brfvBY=s0> ;
#     schema:license <https://www.rijksmuseum.nl/en/data/policy> ;
#     schema:locationCreated "Amsterdam"@nl ;
#     schema:maintainer <https://www.rijksmuseum.nl/> ;
#     schema:name "Portret van Andries Bicker"@nl,
#         "Portret van Andries Bicker, Jacob Houbraken, 1760"@nl ;
#     schema:width 1639 .
#
# <http://example.org/work/ri-nl-RP-P-1937-1196> a schema:CreativeWork,
#         schema:Painting ;
#     schema:creator <http://example.org/person/Q380704> ;
#     schema:height 5391 ;
#     schema:identifier "nl-RP-P-1937-1196" ;
#     schema:image <https://lh3.googleusercontent.com/UUj94Vq-CkMynJ27wZEAOldgXMxFfcwXN0lVob7nyii9M4kLxbGj-wlmHBrBmjp8Uz0gmkI_-O--zj1vDb4F0gsT750=s0> ;
#     schema:license <https://www.rijksmuseum.nl/en/data/policy> ;
#     schema:locationCreated "Amsterdam"@nl ;
#     schema:maintainer <https://www.rijksmuseum.nl/> ;
#     schema:name "Portret van Cornelis Witsen"@nl,
#         "Portret van Cornelis Witsen, Jacob Houbraken, 1796"@nl ;
#     schema:width 3617 .
#
# <http://example.org/work/ri-nl-RP-P-1940-1401> a schema:CreativeWork,
#         schema:Painting ;
#     schema:creator <http://example.org/person/Q12023294> ;
#     schema:height 2500 ;
#     schema:identifier "nl-RP-P-1940-1401" ;
#     schema:image <https://lh4.ggpht.com/e2za7O-FSHqHeMYvM2RkmQM8pCXSAIEGgMs68pGxOk1BnnBcalnnn_YBX-keLGPA6MWW9ovCSLuhMhPx02jSqnq1Eg=s0> ;
#     schema:license <https://www.rijksmuseum.nl/en/data/policy> ;
#     schema:locationCreated "Amsterdam"@nl ;
#     schema:maintainer <https://www.rijksmuseum.nl/> ;
#     schema:name "Portret van Johan van Gool"@nl,
#         "Portret van Johan van Gool, Jacob Houbraken, 1749"@nl ;
#     schema:width 1640 .
#
# <http://example.org/work/ri-nl-RP-P-1940-652> a schema:CreativeWork,
#         schema:Painting ;
#     schema:creator <http://example.org/person/Q12023294> ;
#     schema:identifier "nl-RP-P-1940-652" ;
#     schema:license <https://www.rijksmuseum.nl/en/data/policy> ;
#     schema:locationCreated "Den Haag"@nl ;
#     schema:maintainer <https://www.rijksmuseum.nl/> ;
#     schema:name "Portretten van Jacob Appel, Dirk Dalens en Jan Wandelaar"@nl,
#         "Portretten van Jacob Appel, Dirk Dalens en Jan Wandelaar, Pieter Tanjé, 1751"@nl .
#
# <http://example.org/work/ri-nl-RP-P-1940-749> a schema:CreativeWork,
#         schema:Painting ;
#     schema:creator <http://example.org/person/Q12023294> ;
#     schema:identifier "nl-RP-P-1940-749" ;
#     schema:license <https://www.rijksmuseum.nl/en/data/policy> ;
#     schema:locationCreated "Den Haag"@nl ;
#     schema:maintainer <https://www.rijksmuseum.nl/> ;
#     schema:name "Portretten van Cornelis de Bruyn, Theodorus Netscher en Bonaventura van Overbeek"@nl,
#         "Portretten van Cornelis de Bruyn, Theodorus Netscher en Bonaventura van Overbeek, Jacob Houbraken, 1750"@nl .
#
# <http://example.org/work/ri-nl-RP-P-1941-294> a schema:CreativeWork,
#         schema:Painting ;
#     schema:creator <http://example.org/person/Q2486642> ;
#     schema:height 2500 ;
#     schema:identifier "nl-RP-P-1941-294" ;
#     schema:image <https://lh6.ggpht.com/LZihBhQJIjxQMdwXtZZTztAXubpti49ccBdvZnE0SccdKD-JQ57zCYRgMqku6nOgUD_-NAxMrNt2cYxCW8vI8Vf3cCE=s0> ;
#     schema:license <https://www.rijksmuseum.nl/en/data/policy> ;
#     schema:locationCreated "Amsterdam"@nl ;
#     schema:maintainer <https://www.rijksmuseum.nl/> ;
#     schema:name "Portret van Adriaan Dortsman"@nl,
#         "Portret van Adriaan Dortsman, Pieter van der Plas (II), 1687 - 1708"@nl ;
#     schema:width 1864 .
#
# <http://example.org/work/ri-nl-RP-P-1949-377> a schema:CreativeWork,
#         schema:Painting ;
#     schema:creator <http://example.org/person/Q28144> ;
#     schema:height 2500 ;
#     schema:identifier "nl-RP-P-1949-377" ;
#     schema:image <https://lh3.googleusercontent.com/XE1ohEM6bBbrI0skZ_sre10B3cIRz0VhxQRS6SCAi-4qMopetWp-jAjM7x6k-AeGrMa_21KehLysPz2pMfc2efif6OG2=s0> ;
#     schema:license <https://www.rijksmuseum.nl/en/data/policy> ;
#     schema:locationCreated "Frankrijk"@nl,
#         "Parijs"@nl ;
#     schema:maintainer <https://www.rijksmuseum.nl/> ;
#     schema:name "Gebed voor de maaltijd"@nl,
#         "Gebed voor de maaltijd, Pierre François Basan, 1733 - 1797"@nl ;
#     schema:width 1879 .
#
# <http://example.org/work/ri-nl-RP-P-1960-355> a schema:CreativeWork,
#         schema:Painting ;
#     schema:creator <http://example.org/person/Q28144> ;
#     schema:height 2500 ;
#     schema:identifier "nl-RP-P-1960-355" ;
#     schema:image <https://lh3.ggpht.com/VBwmBP2TCE2GykAtYfaJLk0PI9TqMXVGdKSpv_PZ0F1jt14XKrZBnYmz4Yqot6C1JbgvzKOBqAucYnLaNDnXy2X7cZI=s0> ;
#     schema:license <https://www.rijksmuseum.nl/en/data/policy> ;
#     schema:locationCreated "Nederland"@nl ;
#     schema:maintainer <https://www.rijksmuseum.nl/> ;
#     schema:name "Stilleven met kan, roemer en schaal met citroenen"@nl,
#         "Stilleven met kan, roemer en schaal met citroenen, Carel Lodewijk Dake, 1867 - 1918"@nl ;
#     schema:width 1899 .
#
# <http://example.org/work/ri-nl-RP-P-2004-75-20> a schema:CreativeWork,
#         schema:Painting ;
#     schema:creator <http://example.org/person/Q12023294> ;
#     schema:identifier "nl-RP-P-2004-75-20" ;
#     schema:license <https://www.rijksmuseum.nl/en/data/policy> ;
#     schema:locationCreated "Den Haag"@nl ;
#     schema:maintainer <https://www.rijksmuseum.nl/> ;
#     schema:name "Portret van Cornelis Troost en Gerard Melder"@nl,
#         "Portret van Cornelis Troost en Gerard Melder, Pieter Tanjé, 1750"@nl .
#
# <http://example.org/work/ri-nl-RP-P-BI-1750> a schema:CreativeWork,
#         schema:Painting ;
#     schema:creator <http://example.org/person/Q759784> ;
#     schema:height 2852 ;
#     schema:identifier "nl-RP-P-BI-1750" ;
#     schema:image <https://lh3.googleusercontent.com/o_Hmex3NsttCCFh2RaFENFn-Q9y9-l2SvL3WWQPXkIGWjvEfJvAULZkYDM8xaNBduIgDCWQfKF2OkKINfcHaVYhDvecw=s0> ;
#     schema:license <https://www.rijksmuseum.nl/en/data/policy> ;
#     schema:locationCreated "Amsterdam"@nl ;
#     schema:maintainer <https://www.rijksmuseum.nl/> ;
#     schema:name "Portret van predikant Joannes Vollenhove"@nl,
#         "Portret van predikant Joannes Vollenhove, Abraham de Blois, 1679 - 1717"@nl ;
#     schema:width 2068 .
#
# <http://example.org/work/ri-nl-RP-P-BI-1751> a schema:CreativeWork,
#         schema:Painting ;
#     schema:creator <http://example.org/person/Q759784> ;
#     schema:height 2856 ;
#     schema:identifier "nl-RP-P-BI-1751" ;
#     schema:image <https://lh3.googleusercontent.com/h6MgsQaUNR9quU9KLsfy7qWVFidyRfjLXhMBnW-Mls1Sv-FfZgc9R0L-TJNchpK5W8I8AWYgu3s-TaY1THm4wvn1zyI9=s0> ;
#     schema:license <https://www.rijksmuseum.nl/en/data/policy> ;
#     schema:locationCreated "Amsterdam"@nl ;
#     schema:maintainer <https://www.rijksmuseum.nl/> ;
#     schema:name "Portret van predikant Joannes Vollenhove"@nl,
#         "Portret van predikant Joannes Vollenhove, Abraham de Blois, 1679 - 1717"@nl ;
#     schema:width 1997 .
#
# <http://example.org/work/ri-nl-RP-P-BI-575> a schema:CreativeWork,
#         schema:Painting ;
#     schema:creator <http://example.org/person/Q759784> ;
#     schema:height 3000 ;
#     schema:identifier "nl-RP-P-BI-575" ;
#     schema:image <https://lh5.ggpht.com/UVENM9G4DAusSdvPk3lZrWVd2dIkTz3M81WLiBkZ_EVk7LqKtBRjeot5r4d8dA2It2NYQRXYwadK3Ku8-dpuhuNG3B8=s0> ;
#     schema:license <https://www.rijksmuseum.nl/en/data/policy> ;
#     schema:locationCreated "Nederland"@nl ;
#     schema:maintainer <https://www.rijksmuseum.nl/> ;
#     schema:name "Portret van Lieuwe van Aitzema"@nl,
#         "Portret van Lieuwe van Aitzema, Hendrik Bary, 1666"@nl ;
#     schema:width 1960 .
#
# <http://example.org/work/ri-nl-RP-P-BI-617> a schema:CreativeWork,
#         schema:Painting ;
#     schema:creator <http://example.org/person/Q759784> ;
#     schema:height 2760 ;
#     schema:identifier "nl-RP-P-BI-617" ;
#     schema:image <https://lh3.ggpht.com/XE93XgsU5XCIMSaXyoq9MA4HG5PK1dns3i-xHw1HvTwK2kzkaM5czvc3-5teOm1HZ1gnzwafNkSVti7WiKKOnXCEPuY=s0> ;
#     schema:license <https://www.rijksmuseum.nl/en/data/policy> ;
#     schema:locationCreated "Nederland"@nl ;
#     schema:maintainer <https://www.rijksmuseum.nl/> ;
#     schema:name "Portret van admiraal Cornelis Tromp"@nl,
#         "Portret van admiraal Cornelis Tromp, Hendrik Bary, 1657 - 1707"@nl ;
#     schema:width 2086 .
#
# <http://example.org/work/ri-nl-RP-P-BI-6349X> a schema:CreativeWork,
#         schema:Painting ;
#     schema:creator <http://example.org/person/Q709404> ;
#     schema:height 2089 ;
#     schema:identifier "nl-RP-P-BI-6349X" ;
#     schema:image <https://lh4.ggpht.com/xz8Ail5I3HdRjobdOIzcwgb6D8rKrIT8Pwq81ocv1rT2iGoLMaK9n8FBtqueRZkipaH7HLDyk_oyCdKwMRZ78m2lmw=s0> ;
#     schema:license <https://www.rijksmuseum.nl/en/data/policy> ;
#     schema:locationCreated "Leiden"@nl ;
#     schema:maintainer <https://www.rijksmuseum.nl/> ;
#     schema:name "Binnenplaats met trap"@nl,
#         "Binnenplaats met trap, Jacobus Ludovicus Cornet, 1851"@nl ;
#     schema:width 2500 .
#
# <http://example.org/work/ri-nl-RP-P-BI-6383X> a schema:CreativeWork,
#         schema:Painting ;
#     schema:creator <http://example.org/person/Q709404> ;
#     schema:height 2500 ;
#     schema:identifier "nl-RP-P-BI-6383X" ;
#     schema:image <https://lh3.ggpht.com/w3KJH43mWV3sv5VjrNR_NkDwJJLvzHi5DWKT3Ch_IuNP7yJgmCsUKCOSPYKAhmo1vw0LLRX0y-XnauK7RL1Jlx6UEtSp=s0> ;
#     schema:license <https://www.rijksmuseum.nl/en/data/policy> ;
#     schema:locationCreated "Haarlem"@nl,
#         "Leiden"@nl ;
#     schema:maintainer <https://www.rijksmuseum.nl/> ;
#     schema:name "Koopman in zijn kantoor"@nl,
#         "Koopman in zijn kantoor, Jacobus Ludovicus Cornet, 1825 - 1882"@nl ;
#     schema:width 2139 .
#
# <http://example.org/work/ri-nl-RP-P-BI-6385X> a schema:CreativeWork,
#         schema:Painting ;
#     schema:creator <http://example.org/person/Q709404> ;
#     schema:height 2500 ;
#     schema:identifier "nl-RP-P-BI-6385X" ;
#     schema:image <https://lh4.ggpht.com/bcJpxf_2Cy-3Xyqrtta8QuYquqTYHS9Vq9S0zvRYDS_dx203IYdNOrzclcBIn-INmkM8toDItyLIrTkw2ctQSIbCrbk=s0> ;
#     schema:license <https://www.rijksmuseum.nl/en/data/policy> ;
#     schema:locationCreated "Haarlem"@nl,
#         "Leiden"@nl ;
#     schema:maintainer <https://www.rijksmuseum.nl/> ;
#     schema:name "Koopman in zijn kantoor"@nl,
#         "Koopman in zijn kantoor, Jacobus Ludovicus Cornet, 1825 - 1882"@nl ;
#     schema:width 2051 .
#
# <http://example.org/work/ri-nl-RP-P-BI-6386X> a schema:CreativeWork,
#         schema:Painting ;
#     schema:creator <http://example.org/person/Q709404> ;
#     schema:height 2500 ;
#     schema:identifier "nl-RP-P-BI-6386X" ;
#     schema:image <https://lh6.ggpht.com/JLrHZV20-8IQVk_-C-H93U-5PHVX8zNswAVJtcyECjZWmLcIEbPiSWo115SxYXL7BKc8v8Enu-JhWFn-fm0wXkNijQE=s0> ;
#     schema:license <https://www.rijksmuseum.nl/en/data/policy> ;
#     schema:locationCreated "Haarlem"@nl,
#         "Leiden"@nl ;
#     schema:maintainer <https://www.rijksmuseum.nl/> ;
#     schema:name "Koopman in zijn kantoor"@nl,
#         "Koopman in zijn kantoor, Jacobus Ludovicus Cornet, 1825 - 1882"@nl ;
#     schema:width 2086 .
#
# <http://example.org/work/ri-nl-RP-P-BI-6846> a schema:CreativeWork,
#         schema:Painting ;
#     schema:creator <http://example.org/person/Q724192> ;
#     schema:height 2500 ;
#     schema:identifier "nl-RP-P-BI-6846" ;
#     schema:image <https://lh5.ggpht.com/kqgjOpm9Vp-dhey_qrrZrDsrJoRFiaV7IzinLJnyVmFA_GxlMjDBPdTm6DvL_-Od6bM1B7fn88C0TQs2XI_S-5jbKQ=s0> ;
#     schema:license <https://www.rijksmuseum.nl/en/data/policy> ;
#     schema:locationCreated "Delft"@nl ;
#     schema:maintainer <https://www.rijksmuseum.nl/> ;
#     schema:name "Portret van Caspar van Baerle"@nl,
#         "Portret van Caspar van Baerle, Willem Jacobsz. Delff, 1625"@nl ;
#     schema:width 1726 .
#
# <http://example.org/work/ri-nl-RP-P-BI-6888> a schema:CreativeWork,
#         schema:Painting ;
#     schema:creator <http://example.org/person/Q724192> ;
#     schema:height 2500 ;
#     schema:identifier "nl-RP-P-BI-6888" ;
#     schema:image <https://lh6.ggpht.com/p66DNYgznpWl5DOYC2i_0zTwxHTjS-AhNKFbaRH7amU9RcRjld8MysKhCsu0Ph0U1aegAx8Retc3K_bzssgcuel649A=s0> ;
#     schema:license <https://www.rijksmuseum.nl/en/data/policy> ;
#     schema:locationCreated "Delft"@nl ;
#     schema:maintainer <https://www.rijksmuseum.nl/> ;
#     schema:name "Portret van Johann Neander op 26-jarige leeftijd"@nl,
#         "Portret van Johann Neander op 26-jarige leeftijd, Willem Jacobsz. Delff, 1622"@nl ;
#     schema:width 1583 .
#
# <http://example.org/work/ri-nl-RP-P-H-1091> a schema:CreativeWork,
#         schema:Painting ;
#     schema:creator <http://example.org/person/Q167654> ;
#     schema:height 2500 ;
#     schema:identifier "nl-RP-P-H-1091" ;
#     schema:image <https://lh5.ggpht.com/CXQUK0yQw7OaypDUgCM9Hs-zw7khPdOMEE0INGxFAiAdbAEx7vGWeYs4KfMbrYO7O2cMrZwfyt10WNTOqB3xev-JEpym=s0> ;
#     schema:license <https://www.rijksmuseum.nl/en/data/policy> ;
#     schema:maintainer <https://www.rijksmuseum.nl/> ;
#     schema:name "Twee zingende jongens"@nl,
#         "Twee zingende jongens, Wallerant Vaillant, 1658 - 1677"@nl ;
#     schema:width 1994 .
#
# <http://example.org/work/ri-nl-RP-P-OB-17.210> a schema:CreativeWork,
#         schema:Painting ;
#     schema:creator <http://example.org/person/Q514276> ;
#     schema:height 2500 ;
#     schema:identifier "nl-RP-P-OB-17.210" ;
#     schema:image <https://lh4.ggpht.com/r3HGpwWl-R76g1_mY2SposaoOHH-LuunXPGyvtRn3lxmbnKAU626XTDGEkJfnXZn1Q2kOF6_m_6c2x-EHFGRLPfsCZQ=s0> ;
#     schema:license <https://www.rijksmuseum.nl/en/data/policy> ;
#     schema:locationCreated "Amsterdam"@nl,
#         "Dordrecht"@nl ;
#     schema:maintainer <https://www.rijksmuseum.nl/> ;
#     schema:name "Portret van Jakob Zeeus"@nl,
#         "Portret van Jakob Zeeus, Arnold Houbraken, 1706 - 1719"@nl ;
#     schema:width 1809 .
#
# <http://example.org/work/ri-nl-RP-P-OB-17.211> a schema:CreativeWork,
#         schema:Painting ;
#     schema:creator <http://example.org/person/Q514276> ;
#     schema:height 2500 ;
#     schema:identifier "nl-RP-P-OB-17.211" ;
#     schema:image <https://lh3.ggpht.com/Fxkziv1wFDWYyAub5WMU4wT-i00ZJCVk1DiO37M-9KPm4LzLAjwklNdrgw4Okcgdwk-XmD5C-Y831vtTooaQ3RA0xA=s0> ;
#     schema:license <https://www.rijksmuseum.nl/en/data/policy> ;
#     schema:locationCreated "Amsterdam"@nl,
#         "Dordrecht"@nl ;
#     schema:maintainer <https://www.rijksmuseum.nl/> ;
#     schema:name "Portret van Jakob Zeeus"@nl,
#         "Portret van Jakob Zeeus, Arnold Houbraken, 1706 - 1719"@nl ;
#     schema:width 1805 .
#
# <http://example.org/work/ri-nl-RP-P-OB-17.212> a schema:CreativeWork,
#         schema:Painting ;
#     schema:creator <http://example.org/person/Q514276> ;
#     schema:height 1933 ;
#     schema:identifier "nl-RP-P-OB-17.212" ;
#     schema:image <https://lh6.ggpht.com/kqeKkUQUFsLjXSzB3lzjsXRUShcWQqtR6qH-kFUOdCLCtAjcCtDbTlzdyAdBy7hDwMAv2Aqhi717E5xjUbQ1ZSFOcw0=s0> ;
#     schema:license <https://www.rijksmuseum.nl/en/data/policy> ;
#     schema:locationCreated "Amsterdam"@nl,
#         "Dordrecht"@nl ;
#     schema:maintainer <https://www.rijksmuseum.nl/> ;
#     schema:name "Herderin en herder met hun kind"@nl,
#         "Herderin en herder met hun kind, Arnold Houbraken, 1670 - 1719"@nl ;
#     schema:width 2500 .
#
# <http://example.org/work/ri-nl-RP-P-OB-17.278> a schema:CreativeWork,
#         schema:Painting ;
#     schema:creator <http://example.org/person/Q2486642> ;
#     schema:height 2500 ;
#     schema:identifier "nl-RP-P-OB-17.278" ;
#     schema:image <https://lh3.ggpht.com/wXGUAYyHLPJuf4KF7FPqCKadaoDm_xE7Ln2kkPClj-tleo_8lfse0q65F8M8QgMNxJOJz9mDVvz-GQQvjJWqi3bIzA=s0> ;
#     schema:license <https://www.rijksmuseum.nl/en/data/policy> ;
#     schema:locationCreated "Amsterdam"@nl ;
#     schema:maintainer <https://www.rijksmuseum.nl/> ;
#     schema:name "Portret van Adriaan Dortsman"@nl,
#         "Portret van Adriaan Dortsman, Pieter van der Plas (II), 1687 - 1708"@nl ;
#     schema:width 1891 .
#
# <http://example.org/work/ri-nl-RP-P-OB-17.287X> a schema:CreativeWork,
#         schema:Painting ;
#     schema:creator <http://example.org/person/Q2486642> ;
#     schema:height 2500 ;
#     schema:identifier "nl-RP-P-OB-17.287X" ;
#     schema:image <https://lh5.ggpht.com/sWiLo9w4iKMMHEV4CUQqtvoGm3lHUB0Z8Eb2l93owAjl5bszV6ydU12hGn8E5fAEsPpwvoJZB_jcAimfkOas0kzeWGQ=s0> ;
#     schema:license <https://www.rijksmuseum.nl/en/data/policy> ;
#     schema:locationCreated "Delft"@nl ;
#     schema:maintainer <https://www.rijksmuseum.nl/> ;
#     schema:name "Portret van de predikant Nicolaus Ruymvelt"@nl,
#         "Portret van de predikant Nicolaus Ruymvelt, Jeremias van Schaak, 1690 - 1727"@nl ;
#     schema:width 1877 .
#
# <http://example.org/work/ri-nl-RP-P-OB-17.301> a schema:CreativeWork,
#         schema:Painting ;
#     schema:creator <http://example.org/person/Q167654> ;
#     schema:height 2500 ;
#     schema:identifier "nl-RP-P-OB-17.301" ;
#     schema:image <https://lh3.googleusercontent.com/gPgKWdo21aA4xJbehcGCEozpk-pTEvAZjxgJC3MhOTiIOh-1RaWtSrmGZmUCcyNVOg3K4v8UPSDBl4neQH0YPCinu15v=s0> ;
#     schema:license <https://www.rijksmuseum.nl/en/data/policy> ;
#     schema:maintainer <https://www.rijksmuseum.nl/> ;
#     schema:name "Droevige man"@nl,
#         "Droevige man, Aert Schouman, 1720 - 1792"@nl ;
#     schema:width 1934 .
#
# <http://example.org/work/ri-nl-RP-P-OB-28.014> a schema:CreativeWork,
#         schema:Painting ;
#     schema:creator <http://example.org/person/Q12023294> ;
#     schema:height 2500 ;
#     schema:identifier "nl-RP-P-OB-28.014" ;
#     schema:image <https://lh3.googleusercontent.com/XhD4sEX_ZdhVCM0thcDwprbvKBmxSdNB2Nx2c1sjEncUFvAACusQf38zryldLW01XpBhReH_enewlelbmueeH4OuNZJr=s0> ;
#     schema:license <https://www.rijksmuseum.nl/en/data/policy> ;
#     schema:locationCreated "Amsterdam"@nl,
#         "Nederland"@nl ;
#     schema:maintainer <https://www.rijksmuseum.nl/> ;
#     schema:name "Hond en schapen"@nl,
#         "Hond en schapen, Roelof van der Meulen, 1820 - 1833"@nl ;
#     schema:width 1826 .
#
# <http://example.org/work/ri-nl-RP-P-OB-46.476> a schema:CreativeWork,
#         schema:Painting ;
#     schema:creator <http://example.org/person/Q2046773> ;
#     schema:height 1889 ;
#     schema:identifier "nl-RP-P-OB-46.476" ;
#     schema:image <https://lh4.ggpht.com/FrD8QnYiorPrVF7IUSubs2SMY61wWiN-t4YgJY8ynVm-29Hjn5M6DL9wlp1l0aqVB7FeSYwDc7VIL3Q6G68TaOzyQA=s0> ;
#     schema:license <https://www.rijksmuseum.nl/en/data/policy> ;
#     schema:maintainer <https://www.rijksmuseum.nl/> ;
#     schema:name "
@nl ;
#     schema:maintainer <https://www.rijksmuseum.nl/> ;
#     schema:name "Portret van Koenraad van Beuningen"@nl,
#         "Portret van Koenraad van Beuningen, Jacob Houbraken, 1749 - 1759"@nl ;
#     schema:width 1656 .
#
# <http://example.org/work/ri-nl-RP-P-OB-48.830> a schema:CreativeWork,
#         schema:Painting ;
#     schema:creator <http://example.org/person/Q2576955> ;
#     schema:height 2500 ;
#     schema:identifier "nl-RP-P-OB-48.830" ;
#     schema:image <https://lh3.googleusercontent.com/UR96TTzDV2mvCdGNqJoWKV6TKTDq86q7hXIj9SDp0d-RooEDbfhvzZDevZv3WjmMVwGV0wZOhgBzc88aHSdPRt8vGw=s0> ;
# ...
#     schema:height 1695 ;
#     schema:identifier "nl-SK-A-366" ;
#     schema:image <https://lh3.googleusercontent.com/BReoworMYs6Jbq4ufxzHCjatpzK6uZRPQ51Tg6_Rtz_rzUzdR3brC20z5tYLjKQgFjap0vG5qFOtSN0MmAjgaXDmfgeb=s0> ;
#     schema:license <https://www.rijksmuseum.nl/en/data/policy> ;
#     schema:maintainer <https://www.rijksmuseum.nl/> ;
#     schema:name "De dichter op het feest der dieren gekroond door twee apen"@nl,
#         "De dichter op het feest der dieren gekroond door twee apen, Roelant Savery (atelier van), 1623"@nl ;
#     schema:width 2500 .
#
# <http://example.org/work/ri-nl-SK-A-3749> a schema:CreativeWork,
#         schema:Painting ;
#     schema:creator <http://example.org/person/Q2576955> ;
#     schema:height 2500 ;
#     schema:identifier "nl-SK-A-3749" ;
#     schema:image <https://lh3.googleusercontent.com/dwzBh1IZhWOqJDLZLVAowsCe9KL3-gXMeaRud3r0xg80gPJVvEpQdXLuPCn7v4buOoXGDOk3fiLV89Jgzz7A9nk8Vyg=s0> ;
#     schema:license <https://www.rijksmuseum.nl/en/data/policy> ;
#     schema:maintainer <https://www.rijksmuseum.nl/> ;
#     schema:name "Portret van een man, vermoedelijk Christoffel van Gangelt, tweede echtgenoot van Lucretia Boudaen"@nl,
#         "Portret van een man, vermoedelijk Christoffel van Gangelt, tweede echtgenoot van Lucretia Boudaen, Jacob van Loo (toegeschreven aan), 1640 - 1670"@nl ;
#     schema:width 1851 .
#
# <http://example.org/work/ri-nl-SK-A-3750> a schema:CreativeWork,
#         schema:Painting ;
#     schema:creator <http://example.org/person/Q2576955> ;
#     schema:height 2500 ;
#     schema:identifier "nl-SK-A-3750" ;
#     schema:image <https://lh3.googleusercontent.com/t020Tmmu8X0LXzWvsjfCj4hD7T-gNukwYEGaL14iWZIjKc8VVcjUNy2MC7TSRCg9qwsLyICRhMh1T7GAgwsAhHoSgw=s0> ;
#     schema:license <https://www.rijksmuseum.nl/en/data/policy> ;
#     schema:maintainer <https://www.rijksmuseum.nl/> ;
#     schema:name "Portret van een vrouw, vermoedelijk Lucretia Boudaen, echtgenote van Jean Orrt en tweede echtgenote van Christoffel van Gangelt"@nl,
#         "Portret van een vrouw, vermoedelijk Lucretia Boudaen, echtgenote van Jean Orrt en tweede echtgenote van Christoffel van Gangelt, Jacob van Loo (kopie naar), 1640 - 1670"@nl ;
#     schema:width 1847 .
#
# <http://example.org/work/ri-nl-SK-A-3945> a schema:CreativeWork,
#         schema:Painting ;
#     schema:creator <http://example.org/person/Q315996> ;
#     schema:height 2456 ;
#     schema:identifier "nl-SK-A-3945" ;
#     schema:image <https://lh3.googleusercontent.com/CAJN2sEzDBWyAusBYhOrjxLizjRsuv9YBwIaYCurLXUN6JlAdwCQZZISqXEGS-d1n2psvkTirHZHXtHm61kifXqM0v8_=s0> ;
#     schema:license <https://www.rijksmuseum.nl/en/data/policy> ;
#     schema:locationCreated "Noordelijke Nederlanden"@nl ;
#     schema:maintainer <https://www.rijksmuseum.nl/> ;
#     schema:name "Zomer"@nl,
#         "Zomer, Jan van Goyen, 1625"@nl ;
#     schema:width 2500 .
#
# <http://example.org/work/ri-nl-SK-A-489> a schema:CreativeWork,
#         schema:Painting ;
#     schema:creator <http://example.org/person/Q709404> ;
#     schema:height 2500 ;
#     schema:identifier "nl-SK-A-489" ;
#     schema:image <https://lh3.googleusercontent.com/5Si9dyr9x9B-fWsYRI6Q2-sruvgnShkokpC4f_zZaTM-iENbzgeOC207Mn0rEW6pTC003wqbhg8upMKBHtPalehevA=s0> ;
#     schema:license <https://www.rijksmuseum.nl/en/data/policy> ;
#     schema:maintainer <https://www.rijksmuseum.nl/> ;
#     schema:name "De alchemist"@nl,
#         "De alchemist, Thomas Wijck, 1640 - 1677"@nl ;
#     schema:width 2198 .
#
# <http://example.org/work/ri-nl-SK-A-4950> a schema:CreativeWork,
#         schema:Painting ;
#     schema:creator <http://example.org/person/Q2576955> ;
#     schema:height 2500 ;
#     schema:identifier "nl-SK-A-4950" ;
#     schema:image <https://lh3.googleusercontent.com/xIuyngj0TwcDJyZLrxiZ3H546LEtG0MM1UqKoAVDrrvTCxNDzDGvqXnwG1fcYjFTJ6oq61tMdfn-8JSDq5WURPElPDM=s0> ;
#     schema:license <https://www.rijksmuseum.nl/en/data/policy> ;
#     schema:maintainer <https://www.rijksmuseum.nl/> ;
#     schema:name "Zelfportret, circa 1660"@nl,
#         "Zelfportret, circa 1660, Jacob van Loo, 1655 - 1665"@nl ;
#     schema:width 2083 .
#
# <http://example.org/work/ri-nl-SK-A-799> a schema:CreativeWork,
#         schema:Painting ;
#     schema:creator <http://example.org/person/Q759775> ;
#     schema:height 2424 ;
#     schema:identifier "nl-SK-A-799" ;
#     schema:image <https://lh3.googleusercontent.com/D2IPnfkJPa8cPSuhehu5e2aeteqzK5Zb0OzL9-zA4_FHBQHrD8RLT_3XZ9FDYtE64e_cdqTxZF_VfG4MsPcKr90FV6E=s0> ;
#     schema:license <https://www.rijksmuseum.nl/en/data/policy> ;
#     schema:maintainer <https://www.rijksmuseum.nl/> ;
#     schema:name "Stilleven met bloemen"@nl,
#         "Stilleven met bloemen, Hans Bollongier, 1639"@nl ;
#     schema:width 1904 .
#
# <http://example.org/work/ri-nl-SK-A-81> a schema:CreativeWork,
#         schema:Painting ;
#     schema:creator <http://example.org/person/Q2576955> ;
#     schema:height 2199 ;
#     schema:identifier "nl-SK-A-81" ;
#     schema:image <https://lh3.googleusercontent.com/mp5HguufXvqJwMxAFeRwgcH8S3_TKearq_VGjaWtGLcYaSNzhAvfnYOGPa1G-hkOrZ6O85JH6m5dMOE2MsJJdxe0kPY=s0> ;
#     schema:license <https://www.rijksmuseum.nl/en/data/policy> ;
#     schema:maintainer <https://www.rijksmuseum.nl/> ;
#     schema:name "De familie Meebeeck Cruywagen bij de poort van hun buitenhuis aan de Uitweg bij Amsterdam"@nl,
#         "De familie Meebeeck Cruywagen bij de poort van hun buitenhuis aan de Uitweg bij Amsterdam, Jacob van Loo (toegeschreven aan), 1640 - 1645"@nl ;
#     schema:width 2895 .
#
# <http://example.org/work/ri-nl-SK-C-133> a schema:CreativeWork,
#         schema:Painting ;
#     schema:creator <http://example.org/person/Q12023294> ;
#     schema:height 1319 ;
#     schema:identifier "nl-SK-C-133" ;
#     schema:image <https://lh3.ggpht.com/s35vX3vM1HO2OGjhB_Y3gkfV8xlan2KW5dBgQX9pdPbIwa8LtPYQaEixP8-UOiD9Zrm2J1398kzN-gc4M7JgcRcEWpg=s0> ;
#     schema:license <https://www.rijksmuseum.nl/en/data/policy> ;
#     schema:maintainer <https://www.rijksmuseum.nl/> ;
#     schema:name "Arcadisch landschap met herders en vee"@nl,
#         "Arcadisch landschap met herders en vee, Jan van Gool, 1710 - 1763"@nl ;
#     schema:width 2000 .
#
# <http://example.org/work/ri-nl-SK-C-191> a schema:CreativeWork,
#         schema:Painting ;
#     schema:creator <http://example.org/person/Q381801> ;
#     schema:height 2014 ;
#     schema:identifier "nl-SK-C-191" ;
#     schema:image <https://lh3.googleusercontent.com/M-g-PEPeNCaUIN8VaBbVkXW26wFU7IBdRtH9ybVqp7ZLj9HeW3Cj5qq_rgvxkFrqdW8J3LLj7jfBRQawuS5duVxsJLg=s0> ;
#     schema:license <https://www.rijksmuseum.nl/en/data/policy> ;
#     schema:maintainer <https://www.rijksmuseum.nl/> ;
#     schema:name "Riviergezicht bij winter"@nl,
#         "Riviergezicht bij winter, Aert van der Neer, ca. 1655 - ca. 1660"@nl ;
#     schema:width 2500 .
#
# <http://example.org/work/ri-nl-SK-C-2> a schema:CreativeWork,
#         schema:Painting ;
#     schema:creator <http://example.org/person/Q380704> ;
#     schema:height 1034 ;
#     schema:identifier "nl-SK-C-2" ;
#     schema:image <https://lh3.googleusercontent.com/kmCDKP1kMN72zB-7CHBOBdCnyU3Z-NW7WIzuN_sIqm5n9xf6lG4oTtfcWsGW8qhbVYuwSDkYlhOglx7z4YaFL8UeFWU=s0> ;
#     schema:license <https://www.rijksmuseum.nl/en/data/policy> ;
#     schema:maintainer <https://www.rijksmuseum.nl/> ;
#     schema:name "Schuttersmaaltijd ter viering van de Vrede van Munster"@nl,
#         "Schuttersmaaltijd ter viering van de Vrede van Munster, Bartholomeus van der Helst, 1648"@nl ;
#     schema:width 2500 .
#
# <http://example.org/work/ri-nl-SK-C-251> a schema:CreativeWork,
#         schema:Painting ;
#     schema:creator <http://example.org/person/Q41264> ;
#     schema:height 3000 ;
#     schema:identifier "nl-SK-C-251" ;
#     schema:image <https://lh3.googleusercontent.com/n7X03-aBMaHLQmd9UZXy0WSO81bLI376BMv8tjXfah_-BqdJURY-FoyX_YJKj5WuV5j3P8rLNEHM-T8jJztag9FQZkD3=s0> ;
#     schema:license <https://www.rijksmuseum.nl/en/data/policy> ;
#     schema:maintainer <https://www.rijksmuseum.nl/> ;
#     schema:name "Brieflezende vrouw"@nl,
#         "Brieflezende vrouw, Johannes Vermeer, ca. 1663"@nl ;
#     schema:width 2502 .
#
# <http://example.org/work/ri-nl-SK-C-370> a schema:CreativeWork,
#         schema:Painting ;
#     schema:creator <http://example.org/person/Q550401> ;
#     schema:height 2215 ;
#     schema:identifier "nl-SK-C-370" ;
#     schema:image <https://lh3.googleusercontent.com/zWd-l_Fjo6KhldQOUlh_kBbYf9cIwVV0kIypO1xWETwQ0b0clGP2Igfaoum1SpJNCAfeqZfkIVYokzj4Qg0GAtrCXSI=s0> ;
#     schema:license <https://www.rijksmuseum.nl/en/data/policy> ;
#     schema:maintainer <https://www.rijksmuseum.nl/> ;
#     schema:name "Vier doelheren der Kloveniersdoelen, Amsterdam, 1642"@nl,
#         "Vier doelheren der Kloveniersdoelen, Amsterdam, 1642, Govert Flinck, 1642"@nl ;
#     schema:width 3000 .
#
# <http://example.org/work/ri-nl-SK-C-371> a schema:CreativeWork,
#         schema:Painting ;
#     schema:creator <http://example.org/person/Q550401> ;
#     schema:height 2500 ;
#     schema:identifier "nl-SK-C-371" ;
#     schema:image <https://lh3.googleusercontent.com/HnnjmcsmaQL7rH47kDlBz6fxRNeTmoC_u6FVMfA0rkG8F_2l7JIskZEbJCmHB-1SLQ9U8AyMrxfAOwt6i63HVrOPWA=s0> ;
#     schema:license <https://www.rijksmuseum.nl/en/data/policy> ;
#     schema:maintainer <https://www.rijksmuseum.nl/> ;
#     schema:name "Officieren en andere schutters van wijk XVIII in Amsterdam onder leiding van kapitein Albert Bas en luitenant Lucas Conijn"@nl,
#         "Officieren en andere schutters van wijk XVIII in Amsterdam onder leiding van kapitein Albert Bas en luitenant Lucas Conijn, Govert Flinck, 1645"@nl ;
#     schema:width 1770 .
#
# <http://example.org/work/ri-nl-SK-C-374> a schema:CreativeWork,
#         schema:Painting ;
#     schema:creator <http://example.org/person/Q167654> ;
#     schema:height 1380 ;
#     schema:identifier "nl-SK-C-374" ;
#     schema:image <https://lh4.ggpht.com/w-9ruGKvMxcvzBn4hhRICkisIP5U05xD2bNthIWO8hb62h24zcMgj76LTdLA15sS8CFh9AQHioRLgNisR0TnftamgGmY=s0> ;
#     schema:license <https://www.rijksmuseum.nl/en/data/policy> ;
#     schema:maintainer <https://www.rijksmuseum.nl/> ;
#     schema:name "Schutters van wijk XI onder leiding van kapitein Reynier Reael, bekend als ‘De magere compagnie’"@nl,
#         "Schutters van wijk XI onder leiding van kapitein Reynier Reael, bekend als ‘De magere compagnie’, Frans Hals, Pieter Codde, 1637"@nl ;
#     schema:width 2928 .
#
# <http://example.org/work/ri-nl-SK-C-447> a schema:CreativeWork,
#         schema:Painting ;
#     schema:creator <http://example.org/person/Q142710> ;
#     schema:height 2180 ;
#     schema:identifier "nl-SK-C-447" ;
#     schema:image <https://lh6.ggpht.com/tWo3dUzWnf-RKgV-Jahh0vppBFmE0LrNuA_bfNUViWeQ8MkF7yShuPHm0-ncWdf-MqHusJ1wOi8jBZ3JaPR93-Yre70=s0> ;
#     schema:license <https://www.rijksmuseum.nl/en/data/policy> ;
#     schema:maintainer <https://www.rijksmuseum.nl/> ;
#     schema:name "Everzwijnjacht in een rotsachtig landschap"@nl,
#         "Everzwijnjacht in een rotsachtig landschap, Roelant Savery, 1620"@nl ;
#     schema:width 2972 .
#
# <http://example.org/person/Q265398> a ns1:Person,
#         schema:Person ;
#     ns1:name "Clara Peeters" ;
#     schema:identifier "Q265398" ;
#     schema:sameAs <http://www.wikidata.org/entity/Q265398>,
#         <https://viaf.org/viaf/813644> .
#
# <http://example.org/person/Q684987> a ns1:Person,
#         schema:Person ;
#     ns1:name "Cornelis Droochsloot" ;
#     schema:identifier "Q684987" ;
#     schema:sameAs <http://www.wikidata.org/entity/Q684987>,
#         <https://viaf.org/viaf/95697903> .
#
# <http://example.org/person/Q759747> a ns1:Person,
#         schema:Person ;
#     ns1:name "Evert van Aelst" ;
#     schema:identifier "Q759747" ;
#     schema:sameAs <http://www.wikidata.org/entity/Q759747>,
#         <https://viaf.org/viaf/90812626> .
#
# <http://example.org/person/Q759775> a ns1:Person,
#         schema:Person ;
#     ns1:name "Hans Bollongier" ;
#     schema:identifier "Q759775" ;
#     schema:sameAs <http://www.wikidata.org/entity/Q759775>,
#         <https://viaf.org/viaf/56883813> .
#
# <http://example.org/person/Q472522> a ns1:Person,
#         schema:Person ;
#     ns1:name "Balthasar van der Ast" ;
#     schema:identifier "Q472522" ;
#     schema:sameAs <http://www.wikidata.org/entity/Q472522>,
#         <https://viaf.org/viaf/57514749> .
#
# <http://example.org/person/Q28144> a ns1:Person,
#         schema:Person ;
#     ns1:name "Willem Kalf" ;
#     schema:identifier "Q28144" ;
#     schema:sameAs <http://www.wikidata.org/entity/Q28144>,
#         <https://viaf.org/viaf/52484309> .
#
# <http://example.org/person/Q12023294> a ns1:Person,
#         schema:Person ;
#     ns1:name "Jan van Gool" ;
#     schema:identifier "Q12023294" ;
#     schema:sameAs <http://www.wikidata.org/entity/Q12023294>,
#         <https://viaf.org/viaf/57416265> .
#
# <http://example.org/person/Q142710> a ns1:Person,
#         schema:Person ;
#     ns1:name "Roelant Savery" ;
#     schema:identifier "Q142710" ;
#     schema:sameAs <http://www.wikidata.org/entity/Q142710>,
#         <https://viaf.org/viaf/5728201> .
#
# <http://example.org/person/Q167654> a ns1:Person,
#         schema:Person ;
#     ns1:name "Frans Hals" ;
#     schema:identifier "Q167654" ;
#     schema:sameAs <http://www.wikidata.org/entity/Q167654>,
#         <https://viaf.org/viaf/100165653> .
#
# <http://example.org/person/Q2046773> a ns1:Person,
#         schema:Person ;
#     ns1:name "Govert van der Leeuw" ;
#     schema:identifier "Q2046773" ;
#     schema:sameAs <http://www.wikidata.org/entity/Q2046773>,
#         <https://viaf.org/viaf/61820157> .
#
# <http://example.org/person/Q2486642> a ns1:Person,
#         schema:Person ;
#     ns1:name "David van der Plas" ;
#     schema:identifier "Q2486642" ;
#     schema:sameAs <http://www.wikidata.org/entity/Q2486642>,
#         <https://viaf.org/viaf/22412408> .
#
# <http://example.org/person/Q2576955> a ns1:Person,
#         schema:Person ;
#     ns1:name "Jacob van Loo" ;
#     schema:identifier "Q2576955" ;
#     schema:sameAs <http://www.wikidata.org/entity/Q2576955>,
#         <https://viaf.org/viaf/95460534> .
#
# <http://example.org/person/Q315996> a ns1:Person,
#         schema:Person ;
#     ns1:name "Jan van Goyen" ;
#     schema:identifier "Q315996" ;
#     schema:sameAs <http://www.wikidata.org/entity/Q315996>,
#         <https://viaf.org/viaf/14817785> .
#
# <http://example.org/person/Q380704> a ns1:Person,
#         schema:Person ;
#     ns1:name "Bartholomeus van der Helst" ;
#     schema:identifier "Q380704" ;
#     schema:sameAs <http://www.wikidata.org/entity/Q380704>,
#         <https://viaf.org/viaf/5995918> .
#
# <http://example.org/person/Q381801> a ns1:Person,
#         schema:Person ;
#     ns1:name "Aert van der Neer" ;
#     schema:identifier "Q381801" ;
#     schema:sameAs <http://www.wikidata.org/entity/Q381801>,
#         <https://viaf.org/viaf/51959012> .
#
# <http://example.org/person/Q41264> a ns1:Person,
#         schema:Person ;
#     ns1:name "Johannes Vermeer" ;
#     schema:identifier "Q41264" ;
#     schema:sameAs <http://www.wikidata.org/entity/Q41264>,
#         <https://viaf.org/viaf/51961439> .
#
# <http://example.org/person/Q514276> a ns1:Person,
#         schema:Person ;
#     ns1:name "Arnold Houbraken" ;
#     schema:identifier "Q514276" ;
#     schema:sameAs <http://www.wikidata.org/entity/Q514276>,
#         <https://viaf.org/viaf/74086960> .
#
# <http://example.org/person/Q550401> a ns1:Person,
#         schema:Person ;
#     ns1:name "Govert Flinck" ;
#     schema:identifier "Q550401" ;
#     schema:sameAs <http://www.wikidata.org/entity/Q550401>,
#         <https://viaf.org/viaf/29801997> .
#
# <http://example.org/person/Q709404> a ns1:Person,
#         schema:Person ;
#     ns1:name "Thomas Wijck" ;
#     schema:identifier "Q709404" ;
#     schema:sameAs <http://www.wikidata.org/entity/Q709404>,
#         <https://viaf.org/viaf/40268564> .
#
# <http://example.org/person/Q724192> a ns1:Person,
#         schema:Person ;
#     ns1:name "David Bailly" ;
#     schema:identifier "Q724192" ;
#     schema:sameAs <http://www.wikidata.org/entity/Q724192>,
#         <https://viaf.org/viaf/61820967> .
#
# <http://example.org/person/Q759784> a ns1:Person,
#         schema:Person ;
#     ns1:name "Jan de Baen" ;
#     schema:identifier "Q759784" ;
#     schema:sameAs <http://www.wikidata.org/entity/Q759784>,
#         <https://viaf.org/viaf/95822303> .

# %% [markdown]
# ### Accessing Harvard Art Museums
#
# Now, we will retrieve information from the Harvard Art Museums repository. We will use the VIAF identifier retrieved from Wikidata to identify persons and paintings by means of the API.
# See, for exmaple, the following URL https://api.harvardartmuseums.org/person?q=viaf_id:64013650&apikey=XXXX

# %%
for index, row in ga_df.iterrows():
    
    idWikidata = str(row['item.value'].replace('http://www.wikidata.org/entity/',''))
    
    person = URIRef("http://example.org/person/" + idWikidata)
    
    #print(row['viaf.value'])
    #https://api.harvardartmuseums.org/person?q=viaf_id:64013650&apikey=ab62f9f8-395d-4945-b7cf-a854e4557472
    response = requests.get('https://api.harvardartmuseums.org/person?apikey='+ ham_key +'&q=viaf_id:' + row['viaf.value']) 
  
    idWikidata = str(row['item.value'].replace('http://www.wikidata.org/entity/',''))
    
    person = URIRef("http://example.org/person/" + idWikidata)
    g.add((person, RDF.type, SDO.Person))
    

    hdata = response.json()
    if hdata['info']['totalrecords'] > 0:
        for record in hdata['records']:
            response = requests.get('https://api.harvardartmuseums.org/object?apikey=ab62f9f8-395d-4945-b7cf-a854e4557472&person=' + str(record['id'])) 
            hdataimages = response.json()
            
            for r in hdataimages['records']:
                work = URIRef("http://example.org/work/ham-" + str(r['objectid']))
        
                # Add triples using store's add() method.
                g.add((work, RDF.type, SDO.CreativeWork))
                g.add((work, RDF.type, SDO.Painting))
                g.add((work, SDO.creator, person))

                g.add((work, SDO.name, Literal(r['title'], lang="en")))
                g.add((work, SDO.description, Literal(r['provenance'], lang="en")))
                g.add((work, SDO.identifier, Literal(r['objectid'])))
                g.add((work, SDO.maintainer, URIRef('https://api.harvardartmuseums.org')))
                g.add((work, SDO.license, URIRef('https://github.com/harvardartmuseums/api-docs#terms-of-use')))
                for ham in r['images']:
                    g.add((work, SDO.image, URIRef(ham['baseimageurl'])))

# %% [markdown]
# ### Let's see the result

# %%
g.serialize(destination='golden-age.n3', format='n3')

# %% [markdown]
# ## Create Data Package
# [Data Package](https://pypi.org/project/datapackage/) is a simple container format for describing a coherent collection of data in a single 'package'. It provides the basis for convenient delivery, installation and management of datasets. There is a Python library for working with Data Packages. The descriptor consists of a JSON file describing the content which is automatically created using the infer method. Below we see the descriptor of our extracted dataset.

# %%
package = Package()
package.infer('golden-age.n3')
package.descriptor
# Out:
# {'profile': 'data-package',
#  'resources': [{'path': 'golden-age.n3',
#    'profile': 'data-resource',
#    'name': 'golden-age',
#    'format': 'n3',
#    'mediatype': 'text/n3',
#    'encoding': 'utf-8'}]}

# %% [markdown]
# ### Save the data package
#
# The Data Package contains the data and the descriptor as a zip file that can be reused by others researchers.

# %%
package.save('datapackage.zip')
# Out:
# True

# %% [markdown]
# ### How many authors contains a place of burial?

# %%
df = libraries_df[libraries_df['placeofburialLabel.value'].notnull()]
len(df)
# Out:
# 3159

# %% [markdown]
# ### Create a chart to visualize the authors per institution in the dataset

# %%
ax = libraries_df['org.value'].value_counts().plot(kind='bar',
                                    figsize=(14,8),
                                    title="Number of authors in the 17th century per library")
ax.set_xlabel("Library")
ax.set_ylabel("Authors")
plt.show()

# %% [markdown]
# ## Identifying the most common causes of death

# %%
ax = libraries_df['deathcauseLabel.value'].value_counts().plot(kind='bar',
                                    figsize=(14,8),
                                    title="Causes of death of authors in the 17th century")
ax.set_xlabel("Cause of death")
ax.set_ylabel("Number of authors")
plt.show()

# %% [markdown]
# ### Splitting occupation field
#
# We create a new dataframe for the occupation information. The field is splited using the character '|'. Given an author, we will obtain a row per each occupation.

# %%
columns = ['item.value','occupationLabel.value']
occupation_df = pd.DataFrame(libraries_df, columns=columns)
occupation_df.head()
# Out:
#                                  item.value  \
# 0   http://www.wikidata.org/entity/Q3766070
# 1   http://www.wikidata.org/entity/Q1698179
# 2   http://www.wikidata.org/entity/Q8084303
# 3  http://www.wikidata.org/entity/Q98923992
# 4   http://www.wikidata.org/entity/Q4194354
#
#                                occupationLabel.value
# 0  http://www.wikidata.org/entity/Q214917|http://...
# 1            http://www.wikidata.org/entity/Q4964182
# 2  http://www.wikidata.org/entity/Q36834|http://w...
# 3
# 4  http://www.wikidata.org/entity/Q13365770|http:...

# %%
# Step 1
# We start with creating a new dataframe from the series with EmployeeId as the index
occupation_df = pd.DataFrame(libraries_df['occupationLabel.value'].str.split('|').tolist(), index=libraries_df['item.value']).stack()

# Step 2
# We now want to get rid of the secondary index
# To do this, we will make item.value as a column (it can't be an index since the values will be duplicated)
occupation_df = occupation_df.reset_index([0, 'item.value'])

# Step 3
# The final step is to set the column names as we want them
occupation_df.columns = ['item.value', 'occupationLabel.value']
occupation_df.head()
# Out:
#                                 item.value  \
# 0  http://www.wikidata.org/entity/Q3766070
# 1  http://www.wikidata.org/entity/Q3766070
# 2  http://www.wikidata.org/entity/Q3766070
# 3  http://www.wikidata.org/entity/Q1698179
# 4  http://www.wikidata.org/entity/Q8084303
#
#                      occupationLabel.value
# 0   http://www.wikidata.org/entity/Q214917
# 1    http://www.wikidata.org/entity/Q49757
# 2    http://www.wikidata.org/entity/Q36180
# 3  http://www.wikidata.org/entity/Q4964182
# 4    http://www.wikidata.org/entity/Q36834

# %%
len(occupation_df)
# Out:
# 67580

# %% [markdown]
# ## Getting the most common occupations
#
# Pandas provides many functionalities to group our data. For instance, the most common occupations are listed below.

# %%
occupation_df.groupby("occupationLabel.value")['item.value'].count().reset_index(name='count').sort_values(['count'], ascending=False).head(10)
# Out:
#                        occupationLabel.value  count
# 613    http://www.wikidata.org/entity/Q36180   5237
# 0                                              3707
# 4    http://www.wikidata.org/entity/Q1028181   3400
# 620    http://www.wikidata.org/entity/Q36834   2791
# 380   http://www.wikidata.org/entity/Q201788   2402
# 80   http://www.wikidata.org/entity/Q1234713   2331
# 701    http://www.wikidata.org/entity/Q49757   2324
# 857    http://www.wikidata.org/entity/Q82955   2260
# 233  http://www.wikidata.org/entity/Q1622272   2154
# 487   http://www.wikidata.org/entity/Q250867   1490

# %% [markdown]
# ### Create a graph to identify patterns in occupation information
#
# Each Wikidata link corresponds to a label as is shown below. We will analyse the most common occupations using a graph chart based on the Pyhon library NetworkX. It permits the use of a Pandas dataframe as a source.

# %%
# Build your graph
G = nx.from_pandas_edgelist(occupation_df, 'item.value', 'occupationLabel.value')

labeldict = {}
labeldict["http://www.wikidata.org/entity/Q214917"] = "playwright"
labeldict["http://www.wikidata.org/entity/Q49757"] = "poet"
#labeldict["https://www.wikidata.org/wiki/Q36180"] = "writer"
labeldict["https://www.wikidata.org/wiki/Q1622272"] = "university teacher"
labeldict["http://www.wikidata.org/entity/Q36834"] = "composer"
labeldict["https://www.wikidata.org/wiki/Q1028181"] = "painter"
labeldict["https://www.wikidata.org/wiki/Q201788"] = "historian"
labeldict["http://www.wikidata.org/entity/Q1234713"] = "theologian"
labeldict["http://www.wikidata.org/entity/Q82955"] = "politician"

# Plot it
nx.draw(G, labels=labeldict, with_labels = True)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-8a30d541f63a> in <module>
#      14
#      15 # Plot it
# ---> 16 nx.draw(G, labels=labeldict, with_labels = True)
#      17
#      18 plt.show()
#
# ~/.local/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py in draw(G, pos, ax, **kwds)
#     123         kwds['with_labels'] = 'labels' in kwds
#     124
# --> 125     draw_networkx(G, pos=pos, ax=ax, **kwds)
#     126     ax.set_axis_off()
#     127     plt.draw_if_interactive()
#
# ~/.local/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py in draw_networkx(G, pos, arrows, with_labels, **kwds)
#     275     edge_collection = draw_networkx_edges(G, pos, arrows=arrows, **kwds)
#     276     if with_labels:
# --> 277         draw_networkx_labels(G, pos, **kwds)
#     278     plt.draw_if_interactive()
#     279
#
# ~/.local/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py in draw_networkx_labels(G, pos, labels, font_size, font_color, font_family, font_weight, alpha, bbox, ax, **kwds)
#     798     text_items = {}  # there is no text collection so we'll fake one
#     799     for n, label in labels.items():
# --> 800         (x, y) = pos[n]
#     801         if not is_string_like(label):
#     802             label = str(label)  # this makes "1" and 1 labeled the same
#
# KeyError: 'https://www.wikidata.org/wiki/Q36180'

# %% [markdown]
# In addition, we can remove the labels to obtain a clean graph. The following NetworkX example is configured to work without labels.

# %%
# Build your graph
G = nx.from_pandas_edgelist(occupation_df, 'item.value', 'occupationLabel.value')

# Plot it
nx.draw(G, with_labels = False)

plt.show()

# %% [markdown]
# ## References
# * https://rebeccabilbro.github.io/sparql-from-python/
# * https://ipycytoscape.readthedocs.io/en/latest/
# * https://nbviewer.jupyter.org/github/WillKoehrsen/Data-
# * Analysis/blob/master/plotly/Plotly%20Whirlwind%20Introduction.ipynb
# * https://medium.com/@sureshssarda/pandas-splitting-exploding-a-column-into-multiple-rows-b1b1d59ea12e
# * https://towardsdatascience.com/from-dataframe-to-network-graph-bbb35c8ab675
