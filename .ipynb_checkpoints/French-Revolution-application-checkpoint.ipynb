# %% [markdown]
# ## Library of Congress & Chronicling America
#
# This notebook uses historic newspapers and select digitized newspaper pages provided by [Chronicling America](https://chroniclingamerica.loc.gov/about/) (ISSN 2475-2703).
#
# This example is based on the [*Bourbon News*](https://chroniclingamerica.loc.gov/lccn/sn86069873/) began publication in 1881 in Millersburg, Kentucky under the ownership of Confederate veteran and former farmer Bruce Champ. By 1910, the paper had 3,000 subscribers, ranking it among the largest circulations in the Bluegrass region. The paper continued publishing until 1941.
#
# [Chronicling America](https://chroniclingamerica.loc.gov/about/api/) provides an extensive application programming interface (API) which you can use to explore all of the data. The information is also [published as JSON](https://chroniclingamerica.loc.gov/lccn/sn86069873.json), including the OCR text files.

# %% [markdown]
# ### Setting things up

# %%
from sklearn.feature_extraction.text import CountVectorizer
import pandas as pd
import pickle
import re
import os
from pathlib import Path
import requests
from collections import Counter
import matplotlib.pyplot as plt
from numpy import mean, ones
from scipy.sparse import csr_matrix
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')
import json
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/gustavo/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# Relationships between the volumes, issues and pages are describe in JSON. Each volume has several issues which contain several pages.
#
# <img src="images/graph-loc.png">

# %% [markdown]
# ### Let's retrieve the results!
#
# The *Bourbon News* is accessible via a JSON file including all metadata. The attribute *issues* contains the URLs of all issues that, in turn, contain all *pages*.

# %%
df = pd.read_csv('out.zip')

# %%
df.head(5)
# Out:
#   edition              frequency                                    location  \
# 0     NaN  Daily (except Sunday)  ['Alexandria', 'Alexandria', 'Alexandria']
# 1     NaN    Daily (except Sun.)                             ['New Orleans']
# 2     NaN                 Weekly                                 ['Dubuque']
# 3     NaN                  Daily                                ['New York']
# 4     NaN                  Daily                                ['New York']
#
#                                              subject      date  \
# 0  ['Alexandria (Va.)--Newspapers.', 'Alexandria ...  18480411
# 1  ['Louisiana--New Orleans.--fast--(OCoLC)fst012...  18480325
# 2  ['Dubuque (Iowa)--Newspapers.', 'Dubuque Count...  18480126
# 3  ['New York (N.Y.)--Newspapers.', 'New York (St...  18480504
# 4  ['New York (N.Y.)--Newspapers.', 'New York (St...  18480512
#
#               publisher     language  identifier             provider  \
# 0         Edgar Snowden  ['English']  sn85025007  Library of Congress
# 1       Hayes & M'Clure  ['English']  sn82015378  Library of Congress
# 2         George Greene  ['English']  sn86083352  Library of Congress
# 3  James Gordon Bennett  ['English']  sn83030313  Library of Congress
# 4  James Gordon Bennett  ['English']  sn83030313  Library of Congress
#
#                            title place_of_publication  \
# 0   Alexandria gazette. [volume]     Alexandria, D.C.
# 1   The daily crescent. [volume]   [New Orleans, La.]
# 2        Weekly miners' express.        DuBuque, Iowa
# 3  The New York herald. [volume]      New York [N.Y.]
# 4  The New York herald. [volume]      New York [N.Y.]
#
#                                                 text   id
# 0  P l « I. lS II K 1) 1> A I I. V A X l> l K I*"...  NaN
# 1  DAILY CRESCENT.\nPUBLISHED every DAY — sundays...  NaN
# 2  t'eiiis of the Mines' Express\nTwo\ndollars pe...  NaN
# 3  hc.w YORK HERALD.\nHartk-WMl Onrnar *r vmiimi ...  NaN
# 4  ?iod let hm a.-k? I>ias b? that ln.lul^>'? in ...  NaN

# %%
ax = df['date'].value_counts().plot(kind='bar',
                                    figsize=(16,8),
                                    title="Number of pages per date including the text French Revolution in Chronicling America")
ax.set_xlabel("Period")
ax.set_ylabel("pages")
plt.show()

# %%
df.groupby("date")["title"].count()
# Out:
# date
# 18480101    6
# 18480102    1
# 18480103    3
# 18480104    2
# 18480105    1
#            ..
# 18481227    4
# 18481228    6
# 18481229    3
# 18481230    3
# 18481231    2
# Name: title, Length: 355, dtype: int64

# %%
df.loc[df['date'] == '18480422']
# Out:
#      edition                                          frequency  \
# 22       NaN                                             Weekly
# 23       NaN                                             Weekly
# 44       NaN                   Daily (except Sunday and Monday)
# 78       NaN                                             Weekly
# 219      NaN  Semiweekly (Three times a week during sessions...
# 439      NaN                              Daily (except Sunday)
# 440      NaN                              Daily (except Sunday)
# 639      NaN                                             Weekly
# 769      NaN                                             Weekly
# 863      NaN                                Daily (except Sun.)
# 1258     NaN                                                NaN
# 1342     NaN                                                NaN
#
#                                                location  \
# 22                                       ['Washington']
# 23                                       ['Washington']
# 44                                       ['Washington']
# 78                                       ['Louisville']
# 219                                    ['Indianapolis']
# 439          ['Alexandria', 'Alexandria', 'Alexandria']
# 440          ['Alexandria', 'Alexandria', 'Alexandria']
# 639                                      ['Woodsfield']
# 769                                     ['Baton Rouge']
# 863                                     ['New Orleans']
# 1258  ['http://d-nb.info/gnd/4008456-5', 'http://d-n...
# 1342                 ['http://d-nb.info/gnd/4066009-6']
#
#                                                 subject      date  \
# 22    ['Washington (D.C.)--fast--(OCoLC)fst01204505'...  18480422
# 23    ['Washington (D.C.)--fast--(OCoLC)fst01204505'...  18480422
# 44    ['Washington (D.C.)--fast--(OCoLC)fst01204505'...  18480422
# 78    ['Antislavery movements--Kentucky--Newspapers....  18480422
# 219   ['Indiana--Indianapolis.--fast--(OCoLC)fst0120...  18480422
# 439   ['Alexandria (Va.)--Newspapers.', 'Alexandria ...  18480422
# 440   ['Alexandria (Va.)--Newspapers.', 'Alexandria ...  18480422
# 639   ['Ohio--Woodsfield.--fast--(OCoLC)fst01234336'...  18480422
# 769   ['Baton Rouge (La.)--Newspapers.', 'French Ame...  18480422
# 863   ['Louisiana--New Orleans.--fast--(OCoLC)fst012...  18480422
# 1258       ['http://data.europeana.eu/concept/base/18']  18480422
# 1342  ['http://d-nb.info/gnd/4067510-5', 'http://dat...  18480422
#
#                            publisher               language  identifier  \
# 22                    Gales & Seaton            ['English']  sn83045784
# 23                    Gales & Seaton            ['English']  sn83045784
# 44    Thomas Ritchie & John P. Heiss            ['English']  sn82003410
# 78                        P. Seymour            ['English']  sn82015050
# 219              G.A. & J.P. Chapman            ['English']  sn82014301
# 439                    Edgar Snowden            ['English']  sn85025007
# 440                    Edgar Snowden            ['English']  sn85025007
# 639                      J.R. Morris            ['English']  sn85038115
# 769             Morison & Devalcourt  ['English', 'French']  sn82003383
# 863                  Hayes & M'Clure            ['English']  sn82015378
# 1258        ['The European Library']                 ['de']         NaN
# 1342        ['The European Library']                 ['de']         NaN
#
#                                                provider  \
# 22                                  Library of Congress
# 23                                  Library of Congress
# 44                                  Library of Congress
# 78                                  Library of Congress
# 219                                 Library of Congress
# 439                                 Library of Congress
# 440                                 Library of Congress
# 639                                 Library of Congress
# 769                                 Library of Congress
# 863                                 Library of Congress
# 1258                                ['Teßmann Library']
# 1342  ['Österreichische Nationalbibliothek - Austria...
#
#                                         title place_of_publication  \
# 22    Weekly national intelligencer. [volume]    Washington [D.C.]
# 23    Weekly national intelligencer. [volume]    Washington [D.C.]
# 44                  The daily union. [volume]    Washington [D.C.]
# 78                     The examiner. [volume]      Louisville, Ky.
# 219          Indiana State sentinel. [volume]  Indianapolis [Ind.]
# 439              Alexandria gazette. [volume]     Alexandria, D.C.
# 440              Alexandria gazette. [volume]     Alexandria, D.C.
# 639         The spirit of democracy. [volume]     Woodsfield, Ohio
# 769             Baton-Rouge gazette. [volume]     Baton-Rouge, La.
# 863              The daily crescent. [volume]   [New Orleans, La.]
# 1258          ['Bote für Tirol - 1848-04-22']                  NaN
# 1342          ['Wiener Zeitung - 1848-04-22']                  NaN
#
#                                                    text  \
# 22    NATIONAL INTELLIGENCER.\nTEXAS AND THE UNITED ...
# 23    j?c. n\nkiriT.lc'r-'.'L^, ?...! th.1 ?fa, lh.....
# 44    m"?" """ IITC mt | -A. A/ .2^ llf J*. - -A--.....
# 78    THE EXAMINER.\nJ. ' VAIHiHsN. r.niM.\nr. CWBr....
# 219   3nMana State 0mtuuL\n7CRMAL TIGILASCr. II THE ...
# 439   j\nP l' B 1.1 S H K I) 1) A I I. \ AS l> I K I...
# 440   ALEXANDRIA\nS.VlTRPAY MORNING, APRIL >i, lv*v\...
# 639   THE SPIRIT OF DEMOCRACY.\n. JAB. R. MORRIS, PR...
# 769   m*\nmv n\nIA 7i K\ntu\nJOll* IWHlW»\n• HHITOlt...
# 863   DAILY CRESCENT.\nSPRING FLOWERS.\nby the autho...
# 1258  \ndtttch'dle Verbindung mit dem Oierlandt wied...
# 1342  \nSÄT\nl' i Haus zu verkaufen im Badeort Zschl...
#
#                                                 id
# 22                                             NaN
# 23                                             NaN
# 44                                             NaN
# 78                                             NaN
# 219                                            NaN
# 439                                            NaN
# 440                                            NaN
# 639                                            NaN
# 769                                            NaN
# 863                                            NaN
# 1258  /9200333/BibliographicResource_3000059014836
# 1342  /9200300/BibliographicResource_3000051825054

# %%
df.date.unique()
# Out:
# array(['18480411', '18480325', '18480126', '18480504', '18480512',
#        '18480516', '18480622', '18480522', '18480525', '18480417',
#        '18480426', '18480404', '18480509', '18481209', '18480115',
#        '18480304', '18480401', '18480408', '18480415', '18480422',
#        '18480429', '18480506', '18480520', '18480527', '18480722',
#        '18480916', '18481007', '18481014', '18481028', '18480708',
#        '18480826', '18480302', '18480323', '18480409', '18480425',
#        '18480428', '18480502', '18480526', '18480604', '18480609',
#        '18480610', '18480613', '18480702', '18480714', '18480729',
#        '18480925', '18481020', '18480911', '18481012', '18480407',
#        '18480728', '18480330', '18480518', '18480308', '18480503',
#        '18480510', '18480607', '18480823', '18480621', '18480816',
#        '18480405', '18480128', '18480623', '18481214', '18480805',
#        '18481125', '18480725', '18480414', '18480616', '18480412',
#        '18480501', '18480624', '18480921', '18480603', '18481128',
#        '18480321', '18480318', '18480319', '18480406', '18480420',
#        '18480505', '18480524', '18480619', '18480528', '18480605',
#        '18480625', '18480114', '18480116', '18480101', '18480202',
#        '18480225', '18480421', '18480423', '18481226', '18481230',
#        '18480711', '18480719', '18480713', '18480731', '18481110',
#        '18480311', '18480329', '18480331', '18480402', '18480806',
#        '18480808', '18480809', '18480812', '18480813', '18480815',
#        '18480817', '18480922', '18480929', '18481001', '18480103',
#        '18480106', '18480207', '18480427', '18480629', '18480712',
#        '18480715', '18480718', '18480720', '18480726', '18480802',
#        '18480602', '18480530', '18481117', '18480923', '18481013',
#        '18480721', '18480219', '18480419', '18480617', '18480819',
#        '18480523', '18480515', '18480717', '18480519', '18480517',
#        '18480413', '18480201', '18480211', '18480205', '18480110',
#        '18480124', '18480125', '18480127', '18480807', '18480803',
#        '18480724', '18480801', '18480529', '18480306', '18480328',
#        '18480324', '18480104', '18480701', '18480606', '18481220',
#        '18481228', '18481024', '18481120', '18480507', '18480508',
#        '18480224', '18480804', '18480316', '18481213', '18481206',
#        '18481115', '18481122', '18480601', '18480608', '18480531',
#        '18480926', '18481208', '18481216', '18481109', '18480129',
#        '18481025', '18480418', '18480924', '18481126', '18480107',
#        '18481017', '18480212', '18480327', '18480416', '18480905',
#        '18480904', '18480831', '18480902', '18480810', '18480811',
#        '18480818', '18480830', '18480822', '18480821', '18481211',
#        '18481019', '18480727', '18480313', '18480301', '18480410',
#        '18480203', '18480229', '18480320', '18480317', '18480322',
#        '18480511', '18480909', '18480908', '18481004', '18481021',
#        '18480403', '18480615', '18480704', '18480906', '18480930',
#        '18480630', '18480424', '18480221', '18481215', '18480829',
#        '18480825', '18480303', '18480315', '18480309', '18480310',
#        '18480314', '18480307', '18480118', '18480119', '18480113',
#        '18480204', '18480122', '18481124', '18480913', '18481130',
#        '18480705', '18481103', '18480209', '18480513', '18480614',
#        '18481227', '18481129', '18481030', '18481202', '18481219',
#        '18480108', '18480226', '18481118', '18481106', '18481121',
#        '18480707', '18480117', '18480120', '18480111', '18480121',
#        '18480112', '18480912', '18480706', '18481207', '18481015',
#        '18481104', '18481113', '18481102', '18481111', '18481026',
#        '18480824', '18480918', '18481016', '18481127', '18481123',
#        '18480214', '18480305', '18481010', '18481205', '18480703',
#        '18481023', '18481009', '18481221', '18480620', '18480710',
#        '18481114', '18481223', '18481203', '18481108', '18480927',
#        '18480628', '18480626', '18481231', '18481224', '18480901',
#        '18481031', '18480914', '18480919', '18481204', '18481116',
#        '18480312', '18480903', '18481119', '18481212', '18481022',
#        '18480730', '18480716', '18480827', '18480820', '18480917',
#        '18480430', '18480521', '18480910', '18480326', '18481002',
#        '18481006', '18480612', '18480218', '18480215', '18481005',
#        '18480920', '18480723', '18480208', '18480228', '18481222',
#        '18481229', '18481003', '18480131', '18480907', '18481201',
#        '18480217', '18480210', '18480123', '18481018', '18480709',
#        '18480627', '18481107', '18480928', '18480915', '18480514',
#        '18480618', '18481218', '18480213', '18481029', '18481008',
#        '18481101', '18480223', '18480828', '18481225', '18480814',
#        '18481105', '18480102', '18480611', '18481217', '18480105'],
#       dtype=object)

# %%
df.language.astype(str).unique()
# Out:
# array(["['English']", "['nl']", "['de']", "['English', 'French']",
#        "['English', 'Hawaiian']"], dtype=object)

# %% [markdown]
# ### How many issues?

# %%
df.count()
# Out:
# edition                   16
# frequency                900
# location                1900
# subject                 1900
# date                    1900
# publisher               1877
# language                1900
# identifier               900
# provider                1900
# title                   1900
# place_of_publication     900
# text                    1899
# id                      1000
# dtype: int64

# %%
df.location.astype(str).unique()
# Out:
# array(["['Alexandria', 'Alexandria', 'Alexandria']", "['New Orleans']",
#        "['Dubuque']", "['New York']", "['Richmond']", "['Hillsdale']",
#        "['Honolulu']", "['Washington']", "['Baltimore']", "['Lancaster']",
#        "['Montpelier']", "['Iowa City']", "['Louisville']", "['Ottawa']",
#        "['Wilmington']", "['Saint Johnsbury']", "['Middlebury']",
#        "['Bellows Falls', 'Brattleboro', 'Ludlow']", "['Evansville']",
#        "['Indianapolis']", "['Sunbury']", "['Charles Town']",
#        "['Fayetteville']", "['Upper Sandusky']", "['Raleigh']",
#        "['Carrollton']", "['Woodsfield']", "['Camden']", "['Staunton']",
#        "['Burlington']", "['Edgefield']", "['Wheeling']",
#        "['Bowling Green', 'Louisiana']", "['Brandon', 'Montpelier']",
#        "['New Lisbon', 'Salem']", "['Canton']", "['Port Tobacco']",
#        "['Elkton']", "['Joliet', 'Juliet']", "['Ravenna']",
#        "['Mineral Point']", "['Fayette']", "['Charlotte']",
#        "['Ypsilanti']", "['Wetumpka']", "['Warsaw']",
#        "['East Stroudsburg', 'Stroudsburg', 'Milford']", "['Sumter']",
#        "['Kalida']", "['Davenport']", "['Macon']", "['Bath']",
#        "['Hillsboro']", "['Baton Rouge']", "['Plaquemine']",
#        "['http://d-nb.info/gnd/4066009-6']",
#        "['http://d-nb.info/gnd/4030921-6']",
#        "['http://data.europeana.eu/place/base/40150', 'http://data.europeana.eu/place/base/40386', 'http://data.europeana.eu/place/base/40387', 'http://data.europeana.eu/place/base/106']",
#        "['http://d-nb.info/gnd/10159443-4']",
#        "['http://d-nb.info/gnd/4008456-5', 'http://d-nb.info/gnd/4066009-6']",
#        "['http://d-nb.info/gnd/4008099-7']",
#        "['http://data.europeana.eu/place/base/106', 'http://data.europeana.eu/place/base/40964', 'http://data.europeana.eu/place/base/40963', 'http://data.europeana.eu/place/base/40479']",
#        "['http://data.europeana.eu/place/base/78908', 'http://data.europeana.eu/place/base/40361', 'http://data.europeana.eu/place/base/73306', 'http://data.europeana.eu/place/base/106', 'http://data.europeana.eu/place/base/85']",
#        "['http://data.europeana.eu/place/base/40357', 'http://data.europeana.eu/place/base/106', 'http://data.europeana.eu/place/base/40358', 'http://data.europeana.eu/place/base/40481']",
#        "['http://data.europeana.eu/place/base/40521', 'http://data.europeana.eu/place/base/106', 'http://data.europeana.eu/place/base/40522', 'http://data.europeana.eu/place/base/40165']",
#        "['http://data.europeana.eu/place/base/212469', 'http://data.europeana.eu/place/base/83', 'http://data.europeana.eu/place/base/106', 'http://data.europeana.eu/place/base/40481', 'http://data.europeana.eu/place/base/40884', 'http://data.europeana.eu/place/base/40885']",
#        "['http://data.europeana.eu/place/base/40361', 'http://data.europeana.eu/place/base/40150', 'http://data.europeana.eu/place/base/106', 'http://data.europeana.eu/place/base/40360']",
#        "['http://data.europeana.eu/place/base/106', 'http://data.europeana.eu/place/base/40277', 'http://data.europeana.eu/place/base/40279', 'http://data.europeana.eu/place/base/40278']",
#        "['http://data.europeana.eu/place/base/106', 'http://data.europeana.eu/place/base/40954', 'http://data.europeana.eu/place/base/40953']",
#        "['http://data.europeana.eu/place/base/106', 'http://data.europeana.eu/place/base/40709', 'http://data.europeana.eu/place/base/40479', 'http://data.europeana.eu/place/base/40710']",
#        "['http://data.europeana.eu/place/base/40723', 'http://data.europeana.eu/place/base/106', 'http://data.europeana.eu/place/base/40721', 'http://data.europeana.eu/place/base/40722']"],
#       dtype=object)

# %% [markdown]
# ## Normalize different dates and timestamps from different sources to the same output format.

# %%
for index,row in df.iterrows():
    
    try:
        df.loc[index, 'date'] = row['date'].replace('T00:00:00Z','').replace('-','')
    except:
        df.loc[index, 'date'] = ''

# %%
df.head(3)
# Out:
#   edition              frequency                                    location  \
# 0     NaN  Daily (except Sunday)  ['Alexandria', 'Alexandria', 'Alexandria']
# 1     NaN    Daily (except Sun.)                             ['New Orleans']
# 2     NaN                 Weekly                                 ['Dubuque']
#
#                                              subject      date  \
# 0  ['Alexandria (Va.)--Newspapers.', 'Alexandria ...  18480411
# 1  ['Louisiana--New Orleans.--fast--(OCoLC)fst012...  18480325
# 2  ['Dubuque (Iowa)--Newspapers.', 'Dubuque Count...  18480126
#
#          publisher     language  identifier             provider  \
# 0    Edgar Snowden  ['English']  sn85025007  Library of Congress
# 1  Hayes & M'Clure  ['English']  sn82015378  Library of Congress
# 2    George Greene  ['English']  sn86083352  Library of Congress
#
#                           title place_of_publication  \
# 0  Alexandria gazette. [volume]     Alexandria, D.C.
# 1  The daily crescent. [volume]   [New Orleans, La.]
# 2       Weekly miners' express.        DuBuque, Iowa
#
#                                                 text   id
# 0  P l « I. lS II K 1) 1> A I I. V A X l> l K I*"...  NaN
# 1  DAILY CRESCENT.\nPUBLISHED every DAY — sundays...  NaN
# 2  t'eiiis of the Mines' Express\nTwo\ndollars pe...  NaN

# %% [markdown]
# ### Creating a chart to visualize the results
#
# This chart shows the number of resources by date. However, understanding the table is difficult due to the number of results.

# %%
ax = df['date'].value_counts().plot(kind='bar',
                                    figsize=(18,10),
                                    title="Number of resources per date")
ax.set_xlabel("Dates")
ax.set_ylabel("Resources")
plt.show()

# %% [markdown]
# ### We can convert the field date to datetime to extract the month and create a chart

# %%
df['date']= pd.to_datetime(df['date'])

# %%
dates_day_count = df['date'].dt.month.value_counts()
dates_day_count.head(5)
dates_day_count.plot.bar()

# %% [markdown]
# http://docs.deeppavlov.ai/en/master/features/models/ner.html#multilingual-bert-zero-shot-transfer
#
# Multilingual BERT models allow to perform zero-shot transfer from one language to another. The model ner_ontonotes_bert_mult was trained on OntoNotes corpus which has 19 types in the markup schema. The model performance was evaluated on Russian corpus Collection. Results of the transfer are presented in the table below.
#
# note the model is a large file
#
# seleccionar 5 al azar de cada idioma y realizar el ner y hacer tabla con resultados
# No se elimina palabras no existentes, se puede mejorar

# %%
from deeppavlov import configs, build_model

ner_model = build_model(configs.ner.ner_ontonotes_bert_mult, download=True)
# Out:
# 2020-11-22 21:00:07.230 INFO in 'deeppavlov.download'['download'] at line 138: Skipped http://files.deeppavlov.ai/deeppavlov_data/ner_ontonotes_bert_mult_v1.tar.gz download because of matching hashes
# 2020-11-22 21:00:08.557 INFO in 'deeppavlov.download'['download'] at line 138: Skipped http://files.deeppavlov.ai/deeppavlov_data/bert/multi_cased_L-12_H-768_A-12.zip download because of matching hashes
# WARNING:tensorflow:From /home/gustavo/.local/lib/python3.6/site-packages/bert_dp/tokenization.py:125: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
# 2020-11-22 21:00:10.190 INFO in 'deeppavlov.core.data.simple_vocab'['simple_vocab'] at line 115: [loading vocabulary from /home/gustavo/.deeppavlov/models/ner_ontonotes_bert_mult/tag.dict]
# WARNING:tensorflow:From /home/gustavo/.local/lib/python3.6/site-packages/deeppavlov/core/models/tf_model.py:37: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /home/gustavo/.local/lib/python3.6/site-packages/deeppavlov/core/models/tf_model.py:222: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /home/gustavo/.local/lib/python3.6/site-packages/deeppavlov/core/models/tf_model.py:222: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /home/gustavo/.local/lib/python3.6/site-packages/deeppavlov/core/models/tf_model.py:193: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /home/gustavo/.local/lib/python3.6/site-packages/deeppavlov/models/bert/bert_sequence_tagger.py:236: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /home/gustavo/.local/lib/python3.6/site-packages/deeppavlov/models/bert/bert_sequence_tagger.py:314: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /home/gustavo/.local/lib/python3.6/site-packages/bert_dp/modeling.py:178: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /home/gustavo/.local/lib/python3.6/site-packages/bert_dp/modeling.py:418: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From /home/gustavo/.local/lib/python3.6/site-packages/bert_dp/modeling.py:499: The name tf.assert_less_equal is deprecated. Please use tf.compat.v1.assert_less_equal instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /home/gustavo/.local/lib/python3.6/site-packages/bert_dp/modeling.py:366: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /home/gustavo/.local/lib/python3.6/site-packages/bert_dp/modeling.py:680: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.Dense instead.
# WARNING:tensorflow:From /home/gustavo/.local/lib/python3.6/site-packages/tensorflow_core/python/layers/core.py:187: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /home/gustavo/.local/lib/python3.6/site-packages/bert_dp/modeling.py:283: The name tf.erf is deprecated. Please use tf.math.erf instead.
#
# WARNING:tensorflow:Variable *= will be deprecated. Use `var.assign(var * other)` if you want assignment to the variable value or `x = x * y` if you want a new python Tensor object.
# WARNING:tensorflow:From /home/gustavo/.local/lib/python3.6/site-packages/deeppavlov/models/bert/bert_sequence_tagger.py:75: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /home/gustavo/.local/lib/python3.6/site-packages/tensorflow_core/contrib/crf/python/ops/crf.py:213: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From /home/gustavo/.local/lib/python3.6/site-packages/deeppavlov/core/models/tf_model.py:234: The name tf.train.AdadeltaOptimizer is deprecated. Please use tf.compat.v1.train.AdadeltaOptimizer instead.
#
# WARNING:tensorflow:From /home/gustavo/.local/lib/python3.6/site-packages/deeppavlov/core/models/tf_model.py:131: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From /home/gustavo/.local/lib/python3.6/site-packages/deeppavlov/core/models/tf_model.py:131: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /home/gustavo/.local/lib/python3.6/site-packages/deeppavlov/core/models/tf_model.py:94: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /home/gustavo/.local/lib/python3.6/site-packages/tensorflow_core/python/training/moving_averages.py:433: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# WARNING:tensorflow:From /home/gustavo/.local/lib/python3.6/site-packages/deeppavlov/models/bert/bert_sequence_tagger.py:671: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /home/gustavo/.local/lib/python3.6/site-packages/deeppavlov/models/bert/bert_sequence_tagger.py:244: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# WARNING:tensorflow:From /home/gustavo/.local/lib/python3.6/site-packages/deeppavlov/models/bert/bert_sequence_tagger.py:249: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# 2020-11-22 21:00:31.335 INFO in 'deeppavlov.core.models.tf_model'['tf_model'] at line 51: [loading model from /home/gustavo/.deeppavlov/models/ner_ontonotes_bert_mult/model]
# WARNING:tensorflow:From /home/gustavo/.local/lib/python3.6/site-packages/deeppavlov/core/models/tf_model.py:54: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# INFO:tensorflow:Restoring parameters from /home/gustavo/.deeppavlov/models/ner_ontonotes_bert_mult/model

# %%
for index,row in df.iterrows():
    print(ner_model(['Curling World Championship will be held in Antananarivo']))
    print(ner_model([row['text'][400:800]]))
    break
# Out:
# [[['Curling', 'World', 'Championship', 'will', 'be', 'held', 'in', 'Antananarivo']], [['B-EVENT', 'I-EVENT', 'I-EVENT', 'O', 'O', 'O', 'O', 'B-GPE']]]
# [[['\n', 'dream', 'in', '.', '”', 'And', '*', 'o', 'wild', 'and', 'unmanageable', ';', '\n', 'was', 'she', '—', 'oil', ',', 'it', 'wan', "'hocking", 'to', 'proper', 'people', 'to', ':', '\n', 'look', 'at', 'her', '!', 'And', 'then', 'to', 'hear', 'h', '»', '*', 'r', ',', 'too', '!', 'why', '*', '|', '\n', 'she', 'aetiially', 'laughed', 'aloud', ',', 'Kitty', 'Coleman', 'did', '!', 'I', 'j', '\n', 'say', 'Kitty', ',', 'because', 'everybody', 'called', 'her', 'Kitty', '\n', 'but', 'her', 'Aunt', 'Martha', ';', 'she', 'was', 'an', 'orderly', 'gentle', '-', '!', '\n', 'woman', ',', 'who', 'disapproved', 'of', 'loud', 'laughing', ',', '\n', 'romping', ',', 'and', 'nick', '-', 'naming', ',', 'as', 'she', 'did', 'of', 'other', '\n', 'crimes', ',', 'no', 'she', 'always', 'sa']], [['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PERSON', 'I-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PERSON', 'O', 'O', 'O', 'O', 'O', 'B-PERSON', 'O', 'O', 'O', 'O', 'B-PERSON', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']]]
